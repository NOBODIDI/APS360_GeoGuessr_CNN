# %% [markdown]
# <a href="https://colab.research.google.com/github/NOBODIDI/APS360_GeoGuessr_NN/blob/main/primary_model/Joshua's_Tuning_(Inception).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Useful Links
#
# *   Background info: https://cs231n.github.io/transfer-learning/
# *   https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html
# * Finetuning: https://pytorch.org/tutorials/beginner/finetuning_torchvision_models_tutorial.html

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# REMEMBER TO CHANGE RUNTIME TO GPU AND THEN MOUNT GOOGLE DRIVE (ALSO ADD TRAIN_VAL_TEST_SPLIT AS A SHORTCUT TO DRIVE)

# %%
import torch
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
from PIL import Image
import os
import matplotlib.pyplot as plt
import shutil
import time
import copy

# %% [markdown]
# ### Initializing Model

# %%
def init_model(model_name):
    # Initialize these variables which will be set in this if statement. Each of these
    #   variables is model specific.
    net = None
    input_size = 0

    if model_name == "resnet":
        """ WideResnet50 
        https://pytorch.org/vision/master/models/generated/torchvision.models.wide_resnet50_2.html#torchvision.models.wide_resnet50_2
        """
        net = models.wide_resnet50_2(weights='DEFAULT')
        # Freezing all the gradients of the model parameters (TRANSFER LEARNING)
        for param in net.parameters():
            param.requires_grad = True
        num_ftrs = net.fc.in_features
        net.fc = nn.Linear(num_ftrs, num_classes)

    elif model_name == "alexnet":
        """ Alexnet
        https://pytorch.org/vision/master/models/generated/torchvision.models.alexnet.html#torchvision.models.alexnet
        """
        net = models.alexnet(weights='DEFAULT')
        # Freezing all the gradients of the model parameters (TRANSFER LEARNING)
        for param in net.parameters():
            param.requires_grad = False
        num_ftrs = net.classifier[6].in_features
        net.classifier[6] = nn.Linear(num_ftrs,num_classes)

    elif model_name == "vgg":
        """ VGG11_bn
        https://pytorch.org/vision/master/models/generated/torchvision.models.vgg11_bn.html#torchvision.models.vgg11_bn
        """
        net = models.vgg11_bn(weights='DEFAULT')
        # Freezing all the gradients of the model parameters (TRANSFER LEARNING)
        for param in net.parameters():
            param.requires_grad = False
        num_ftrs = net.classifier[6].in_features
        net.classifier[6] = nn.Linear(num_ftrs,num_classes)

    elif model_name == "inception":
        """ Inception v3
        Be careful, expects (299,299) sized images and has auxiliary output
        https://pytorch.org/vision/master/models/generated/torchvision.models.inception_v3.html#torchvision.models.inception_v3
        """
        net = models.inception_v3(weights='DEFAULT')
        # Freezing all the gradients of the model parameters (TRANSFER LEARNING)
        for param in net.parameters():
            param.requires_grad = True
        # Handle the auxilary net
        num_ftrs = net.AuxLogits.fc.in_features
        net.AuxLogits.fc = nn.Linear(num_ftrs, num_classes)
        # Handle the primary net
        num_ftrs = net.fc.in_features
        net.fc = nn.Linear(num_ftrs,num_classes)

    else:
        print("Invalid model name, exiting...")
        exit()

    # Choosing which parameter gradients to optimize (only at the final FC layers)
    params_to_update = []
    print("Params to learn:")
    for name,param in net.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name,len(param))

    return net, params_to_update

# %% [markdown]
# #### Datasets and Dataloaders (Run ONCE)

# %%
# Loading in Data

# /////////// CHANGE THIS TO TRUE IF YOU WANT TO USE INCEPTION /////////
is_inception = True
# /////////////////////////////////////////////////////////
if is_inception:
    resize = 342
    input_size = 299
else:
    resize = 256
    input_size = 224

# Data augmentation and normalization for training
# Just normalization for validation, test

data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(resize),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
     'test': transforms.Compose([
        transforms.Resize(resize),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

# ////////////////// CHANGE THIS IF NEEDED TO POINT TO THE DATA ////////////////////////
root_path = "/content/drive/MyDrive/APS360 - Deep Learning Project /Colab Notebooks/train_val_test_split"
# ////////////////////////////////////////////////////////////////////////////////

# Fixed PyTorch random seed for reproducible result
torch.manual_seed(1000)

# Create training and validation and test datasets
image_datasets = {x: torchvision.datasets.ImageFolder(os.path.join(root_path, x), 
                                                      data_transforms[x]) for x in ['train', 'val','test']}

classes = image_datasets['train'].classes
# Number of classes
num_classes = len(classes)
print("Total dataset:",len(image_datasets['train'])+len(image_datasets['val'])+len(image_datasets['test']),"\n",
      "\tTrain size:",len(image_datasets['train']),"\n\tVal size:",len(image_datasets['val']),"\n\tTest size:",len(image_datasets['test']))
print("Number of classes:",num_classes)

batch_size = 64
# Create training and validation and test dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, 
                                                   shuffle=True, num_workers=1) for x in ['train', 'val','test']}
# Out:
# Total dataset: 7983
#  	Train size: 5588
# 	Val size: 1596
# 	Test size: 799
# Number of classes: 80

# %% [markdown]
# ### Visualizing sample data (Run ONCE)

# %%
# Visualize some sample data
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp[0].numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

# # obtain one batch of training images
images, labels = next(iter(dataloaders_dict['train']))
print("Images size:",images.shape)
print("Labels size:",labels.shape)

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(10, 9))
for i in np.arange(20):
    ax = fig.add_subplot(4, 20/4, i+1, xticks=[], yticks=[])
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = images[i].numpy().transpose((1,2,0))
    image = std * image + mean
    image = np.clip(image, 0, 1)
    plt.imshow(image)
    ax.set_title(classes[labels[i]])
# Out:
# Images size: torch.Size([64, 3, 224, 224])
# Labels size: torch.Size([64])

# %% [markdown]
# ### Training the Model

# %%
# Training code modified from https://pytorch.org/tutorials/beginner/finetuning_torchvision_models_tutorial.html
def train_model(model, model_name,
                datasets=image_datasets, 
                batch_size=256, 
                learning_rate=0.045, 
                halving_time=10,
                num_epochs=5, 
                aux_coef=0.4, # Inception auxiliary coefficient
                is_inception=False):
  
    since = time.time()
    # ////////////////// CHANGE THIS IF NEEDED TO POINT to your SAVE FOLDER ////////////////////////
    save_path = "/content/drive/MyDrive/APS360 - Deep Learning Project /Colab Notebooks/Hyperparameter Tuning/Resnet Results"
    # ////////////////////////////////////////////////////////////////////////////////
    model_path = os.path.join(save_path, "best_model_{0}_bs{1}_lr{2}_ht{3}_epochs{4}".format(model_name,
                                                                                      batch_size,
                                                                                      learning_rate,
                                                                                      halving_time,
                                                                                      num_epochs))

    dataloaders = {x: torch.utils.data.DataLoader(datasets[x], 
                                                  batch_size=batch_size, 
                                                  shuffle=True, 
                                                  num_workers=1) for x in ['train', 'val']}

    # Observe that some parameters are being optimized
    optimizer = optim.Adam(params_to_update, lr=learning_rate)
    # Setup the loss fxn
    criterion = nn.CrossEntropyLoss()

    val_loss_history = []
    val_acc_history = []
    train_loss_history = []
    train_acc_history = []
    epochs = np.arange(0,num_epochs)

    best_acc = 0.0

    for epoch in range(num_epochs):
        # start_epoch = time.time()
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Learning Rate schedule
        if ((epoch) % (halving_time) == 0) and (epoch != 0):
          learning_rate /= 2
          optimizer = optim.Adam(params_to_update, lr=learning_rate)
          print('////// NEW LEARNING RATE: {:.4f} //////'.format(learning_rate))

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:

                #############################################
                #To Enable GPU Usage
                if use_cuda and torch.cuda.is_available():
                  inputs = inputs.cuda()
                  labels = labels.cuda()
                #############################################

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    # Special case for the loss by summing the final output and the auxiliary output
                    #   but in testing inception because in training it has an auxiliary output. In train
                    #   mode we calculate  only consider the final output.
                    if phase == 'train' and is_inception == True:
                        # From https://discuss.pytorch.org/t/how-to-optimize-inception-model-with-auxiliary-classifiers/7958
                        outputs, aux_outputs = model(inputs)
                        loss1 = criterion(outputs, labels)
                        loss2 = criterion(aux_outputs, labels)
                        loss = loss1 + aux_coef*loss2
                    else:
                        outputs = model(inputs)
                        loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                # ///////// UNCOMMENT IF YOU WANT TO SEE RUNNING LOSS ///////////////////////////
                # print('{} Running Loss: {:.4f} Running Acc: {:.4f}'.format(phase, running_loss, running_corrects))

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = float(running_corrects) / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                torch.save(model.state_dict(), model_path)
                
            if phase == 'val':
                val_acc_history.append(epoch_acc)
                val_loss_history.append(epoch_loss)
            if phase == 'train':
                train_acc_history.append(epoch_acc)
                train_loss_history.append(epoch_loss)

        time_elapsed = time.time() - since
        print('Time elapsed: {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))    
        print('-' * 10)

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    plt.title("Training vs Validation Loss Curve")
    plt.plot(epochs, train_loss_history, label="Train")
    plt.plot(epochs, val_loss_history, label="Validation")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend(loc='best')
    plt.show()

    plt.title("Training vs Validation Accuracy Curve")
    plt.plot(epochs, train_acc_history, label="Train")
    plt.plot(epochs, val_acc_history, label="Validation")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend(loc='best')
    plt.show()

    # load best model weights
    state = torch.load(model_path)
    model.load_state_dict(state)
    return model

# %% [markdown]
# ## Training Model

# %%
# /////////////////////// HERE IS WHERE YOU CHANGE THE MODEL NAME ///////////////////////
model_name = 'inception' # change from 'resnet' to model of choice
model, params_to_update = init_model(model_name) 
# //////////////////////////////////////////////////////////////////////////////////////
use_cuda = True

if use_cuda and torch.cuda.is_available():
  model = model.cuda()
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')

trained_model = train_model(model, model_name, 
                            datasets=image_datasets, 
                            batch_size=64, 
                            learning_rate=0.005, 
                            halving_time=75, 
                            num_epochs=150,
                            aux_coef=0.8,
                            is_inception=True)
# Out:
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
#   0%|          | 0.00/104M [00:00<?, ?B/s]
# Params to learn:
# 	 Conv2d_1a_3x3.conv.weight 32
# 	 Conv2d_1a_3x3.bn.weight 32
# 	 Conv2d_1a_3x3.bn.bias 32
# 	 Conv2d_2a_3x3.conv.weight 32
# 	 Conv2d_2a_3x3.bn.weight 32
# 	 Conv2d_2a_3x3.bn.bias 32
# 	 Conv2d_2b_3x3.conv.weight 64
# 	 Conv2d_2b_3x3.bn.weight 64
# 	 Conv2d_2b_3x3.bn.bias 64
# 	 Conv2d_3b_1x1.conv.weight 80
# 	 Conv2d_3b_1x1.bn.weight 80
# 	 Conv2d_3b_1x1.bn.bias 80
# 	 Conv2d_4a_3x3.conv.weight 192
# 	 Conv2d_4a_3x3.bn.weight 192
# 	 Conv2d_4a_3x3.bn.bias 192
# 	 Mixed_5b.branch1x1.conv.weight 64
# 	 Mixed_5b.branch1x1.bn.weight 64
# 	 Mixed_5b.branch1x1.bn.bias 64
# 	 Mixed_5b.branch5x5_1.conv.weight 48
# 	 Mixed_5b.branch5x5_1.bn.weight 48
# 	 Mixed_5b.branch5x5_1.bn.bias 48
# 	 Mixed_5b.branch5x5_2.conv.weight 64
# 	 Mixed_5b.branch5x5_2.bn.weight 64
# 	 Mixed_5b.branch5x5_2.bn.bias 64
# 	 Mixed_5b.branch3x3dbl_1.conv.weight 64
# 	 Mixed_5b.branch3x3dbl_1.bn.weight 64
# 	 Mixed_5b.branch3x3dbl_1.bn.bias 64
# 	 Mixed_5b.branch3x3dbl_2.conv.weight 96
# 	 Mixed_5b.branch3x3dbl_2.bn.weight 96
# 	 Mixed_5b.branch3x3dbl_2.bn.bias 96
# 	 Mixed_5b.branch3x3dbl_3.conv.weight 96
# 	 Mixed_5b.branch3x3dbl_3.bn.weight 96
# 	 Mixed_5b.branch3x3dbl_3.bn.bias 96
# 	 Mixed_5b.branch_pool.conv.weight 32
# 	 Mixed_5b.branch_pool.bn.weight 32
# 	 Mixed_5b.branch_pool.bn.bias 32
# 	 Mixed_5c.branch1x1.conv.weight 64
# 	 Mixed_5c.branch1x1.bn.weight 64
# 	 Mixed_5c.branch1x1.bn.bias 64
# 	 Mixed_5c.branch5x5_1.conv.weight 48
# 	 Mixed_5c.branch5x5_1.bn.weight 48
# 	 Mixed_5c.branch5x5_1.bn.bias 48
# 	 Mixed_5c.branch5x5_2.conv.weight 64
# 	 Mixed_5c.branch5x5_2.bn.weight 64
# 	 Mixed_5c.branch5x5_2.bn.bias 64
# 	 Mixed_5c.branch3x3dbl_1.conv.weight 64
# 	 Mixed_5c.branch3x3dbl_1.bn.weight 64
# 	 Mixed_5c.branch3x3dbl_1.bn.bias 64
# 	 Mixed_5c.branch3x3dbl_2.conv.weight 96
# 	 Mixed_5c.branch3x3dbl_2.bn.weight 96
# 	 Mixed_5c.branch3x3dbl_2.bn.bias 96
# 	 Mixed_5c.branch3x3dbl_3.conv.weight 96
# 	 Mixed_5c.branch3x3dbl_3.bn.weight 96
# 	 Mixed_5c.branch3x3dbl_3.bn.bias 96
# 	 Mixed_5c.branch_pool.conv.weight 64
# 	 Mixed_5c.branch_pool.bn.weight 64
# 	 Mixed_5c.branch_pool.bn.bias 64
# 	 Mixed_5d.branch1x1.conv.weight 64
# 	 Mixed_5d.branch1x1.bn.weight 64
# 	 Mixed_5d.branch1x1.bn.bias 64
# 	 Mixed_5d.branch5x5_1.conv.weight 48
# 	 Mixed_5d.branch5x5_1.bn.weight 48
# 	 Mixed_5d.branch5x5_1.bn.bias 48
# 	 Mixed_5d.branch5x5_2.conv.weight 64
# 	 Mixed_5d.branch5x5_2.bn.weight 64
# 	 Mixed_5d.branch5x5_2.bn.bias 64
# 	 Mixed_5d.branch3x3dbl_1.conv.weight 64
# 	 Mixed_5d.branch3x3dbl_1.bn.weight 64
# 	 Mixed_5d.branch3x3dbl_1.bn.bias 64
# 	 Mixed_5d.branch3x3dbl_2.conv.weight 96
# 	 Mixed_5d.branch3x3dbl_2.bn.weight 96
# 	 Mixed_5d.branch3x3dbl_2.bn.bias 96
# 	 Mixed_5d.branch3x3dbl_3.conv.weight 96
# 	 Mixed_5d.branch3x3dbl_3.bn.weight 96
# 	 Mixed_5d.branch3x3dbl_3.bn.bias 96
# 	 Mixed_5d.branch_pool.conv.weight 64
# 	 Mixed_5d.branch_pool.bn.weight 64
# 	 Mixed_5d.branch_pool.bn.bias 64
# 	 Mixed_6a.branch3x3.conv.weight 384
# 	 Mixed_6a.branch3x3.bn.weight 384
# 	 Mixed_6a.branch3x3.bn.bias 384
# 	 Mixed_6a.branch3x3dbl_1.conv.weight 64
# 	 Mixed_6a.branch3x3dbl_1.bn.weight 64
# 	 Mixed_6a.branch3x3dbl_1.bn.bias 64
# 	 Mixed_6a.branch3x3dbl_2.conv.weight 96
# 	 Mixed_6a.branch3x3dbl_2.bn.weight 96
# 	 Mixed_6a.branch3x3dbl_2.bn.bias 96
# 	 Mixed_6a.branch3x3dbl_3.conv.weight 96
# 	 Mixed_6a.branch3x3dbl_3.bn.weight 96
# 	 Mixed_6a.branch3x3dbl_3.bn.bias 96
# 	 Mixed_6b.branch1x1.conv.weight 192
# 	 Mixed_6b.branch1x1.bn.weight 192
# 	 Mixed_6b.branch1x1.bn.bias 192
# 	 Mixed_6b.branch7x7_1.conv.weight 128
# 	 Mixed_6b.branch7x7_1.bn.weight 128
# 	 Mixed_6b.branch7x7_1.bn.bias 128
# 	 Mixed_6b.branch7x7_2.conv.weight 128
# 	 Mixed_6b.branch7x7_2.bn.weight 128
# 	 Mixed_6b.branch7x7_2.bn.bias 128
# 	 Mixed_6b.branch7x7_3.conv.weight 192
# 	 Mixed_6b.branch7x7_3.bn.weight 192
# 	 Mixed_6b.branch7x7_3.bn.bias 192
# 	 Mixed_6b.branch7x7dbl_1.conv.weight 128
# 	 Mixed_6b.branch7x7dbl_1.bn.weight 128
# 	 Mixed_6b.branch7x7dbl_1.bn.bias 128
# 	 Mixed_6b.branch7x7dbl_2.conv.weight 128
# 	 Mixed_6b.branch7x7dbl_2.bn.weight 128
# 	 Mixed_6b.branch7x7dbl_2.bn.bias 128
# 	 Mixed_6b.branch7x7dbl_3.conv.weight 128
# 	 Mixed_6b.branch7x7dbl_3.bn.weight 128
# 	 Mixed_6b.branch7x7dbl_3.bn.bias 128
# 	 Mixed_6b.branch7x7dbl_4.conv.weight 128
# 	 Mixed_6b.branch7x7dbl_4.bn.weight 128
# 	 Mixed_6b.branch7x7dbl_4.bn.bias 128
# 	 Mixed_6b.branch7x7dbl_5.conv.weight 192
# 	 Mixed_6b.branch7x7dbl_5.bn.weight 192
# 	 Mixed_6b.branch7x7dbl_5.bn.bias 192
# 	 Mixed_6b.branch_pool.conv.weight 192
# 	 Mixed_6b.branch_pool.bn.weight 192
# 	 Mixed_6b.branch_pool.bn.bias 192
# 	 Mixed_6c.branch1x1.conv.weight 192
# 	 Mixed_6c.branch1x1.bn.weight 192
# 	 Mixed_6c.branch1x1.bn.bias 192
# 	 Mixed_6c.branch7x7_1.conv.weight 160
# 	 Mixed_6c.branch7x7_1.bn.weight 160
# 	 Mixed_6c.branch7x7_1.bn.bias 160
# 	 Mixed_6c.branch7x7_2.conv.weight 160
# 	 Mixed_6c.branch7x7_2.bn.weight 160
# 	 Mixed_6c.branch7x7_2.bn.bias 160
# 	 Mixed_6c.branch7x7_3.conv.weight 192
# 	 Mixed_6c.branch7x7_3.bn.weight 192
# 	 Mixed_6c.branch7x7_3.bn.bias 192
# 	 Mixed_6c.branch7x7dbl_1.conv.weight 160
# 	 Mixed_6c.branch7x7dbl_1.bn.weight 160
# 	 Mixed_6c.branch7x7dbl_1.bn.bias 160
# 	 Mixed_6c.branch7x7dbl_2.conv.weight 160
# 	 Mixed_6c.branch7x7dbl_2.bn.weight 160
# 	 Mixed_6c.branch7x7dbl_2.bn.bias 160
# 	 Mixed_6c.branch7x7dbl_3.conv.weight 160
# 	 Mixed_6c.branch7x7dbl_3.bn.weight 160
# 	 Mixed_6c.branch7x7dbl_3.bn.bias 160
# 	 Mixed_6c.branch7x7dbl_4.conv.weight 160
# 	 Mixed_6c.branch7x7dbl_4.bn.weight 160
# 	 Mixed_6c.branch7x7dbl_4.bn.bias 160
# 	 Mixed_6c.branch7x7dbl_5.conv.weight 192
# 	 Mixed_6c.branch7x7dbl_5.bn.weight 192
# 	 Mixed_6c.branch7x7dbl_5.bn.bias 192
# 	 Mixed_6c.branch_pool.conv.weight 192
# 	 Mixed_6c.branch_pool.bn.weight 192
# 	 Mixed_6c.branch_pool.bn.bias 192
# 	 Mixed_6d.branch1x1.conv.weight 192
# 	 Mixed_6d.branch1x1.bn.weight 192
# 	 Mixed_6d.branch1x1.bn.bias 192
# 	 Mixed_6d.branch7x7_1.conv.weight 160
# 	 Mixed_6d.branch7x7_1.bn.weight 160
# 	 Mixed_6d.branch7x7_1.bn.bias 160
# 	 Mixed_6d.branch7x7_2.conv.weight 160
# 	 Mixed_6d.branch7x7_2.bn.weight 160
# 	 Mixed_6d.branch7x7_2.bn.bias 160
# 	 Mixed_6d.branch7x7_3.conv.weight 192
# 	 Mixed_6d.branch7x7_3.bn.weight 192
# 	 Mixed_6d.branch7x7_3.bn.bias 192
# 	 Mixed_6d.branch7x7dbl_1.conv.weight 160
# 	 Mixed_6d.branch7x7dbl_1.bn.weight 160
# 	 Mixed_6d.branch7x7dbl_1.bn.bias 160
# 	 Mixed_6d.branch7x7dbl_2.conv.weight 160
# 	 Mixed_6d.branch7x7dbl_2.bn.weight 160
# 	 Mixed_6d.branch7x7dbl_2.bn.bias 160
# 	 Mixed_6d.branch7x7dbl_3.conv.weight 160
# 	 Mixed_6d.branch7x7dbl_3.bn.weight 160
# 	 Mixed_6d.branch7x7dbl_3.bn.bias 160
# 	 Mixed_6d.branch7x7dbl_4.conv.weight 160
# 	 Mixed_6d.branch7x7dbl_4.bn.weight 160
# 	 Mixed_6d.branch7x7dbl_4.bn.bias 160
# 	 Mixed_6d.branch7x7dbl_5.conv.weight 192
# 	 Mixed_6d.branch7x7dbl_5.bn.weight 192
# 	 Mixed_6d.branch7x7dbl_5.bn.bias 192
# 	 Mixed_6d.branch_pool.conv.weight 192
# 	 Mixed_6d.branch_pool.bn.weight 192
# 	 Mixed_6d.branch_pool.bn.bias 192
# 	 Mixed_6e.branch1x1.conv.weight 192
# 	 Mixed_6e.branch1x1.bn.weight 192
# 	 Mixed_6e.branch1x1.bn.bias 192
# 	 Mixed_6e.branch7x7_1.conv.weight 192
# 	 Mixed_6e.branch7x7_1.bn.weight 192
# 	 Mixed_6e.branch7x7_1.bn.bias 192
# 	 Mixed_6e.branch7x7_2.conv.weight 192
# 	 Mixed_6e.branch7x7_2.bn.weight 192
# 	 Mixed_6e.branch7x7_2.bn.bias 192
# 	 Mixed_6e.branch7x7_3.conv.weight 192
# 	 Mixed_6e.branch7x7_3.bn.weight 192
# 	 Mixed_6e.branch7x7_3.bn.bias 192
# 	 Mixed_6e.branch7x7dbl_1.conv.weight 192
# 	 Mixed_6e.branch7x7dbl_1.bn.weight 192
# 	 Mixed_6e.branch7x7dbl_1.bn.bias 192
# 	 Mixed_6e.branch7x7dbl_2.conv.weight 192
# 	 Mixed_6e.branch7x7dbl_2.bn.weight 192
# 	 Mixed_6e.branch7x7dbl_2.bn.bias 192
# 	 Mixed_6e.branch7x7dbl_3.conv.weight 192
# 	 Mixed_6e.branch7x7dbl_3.bn.weight 192
# 	 Mixed_6e.branch7x7dbl_3.bn.bias 192
# 	 Mixed_6e.branch7x7dbl_4.conv.weight 192
# 	 Mixed_6e.branch7x7dbl_4.bn.weight 192
# 	 Mixed_6e.branch7x7dbl_4.bn.bias 192
# 	 Mixed_6e.branch7x7dbl_5.conv.weight 192
# 	 Mixed_6e.branch7x7dbl_5.bn.weight 192
# 	 Mixed_6e.branch7x7dbl_5.bn.bias 192
# 	 Mixed_6e.branch_pool.conv.weight 192
# 	 Mixed_6e.branch_pool.bn.weight 192
# 	 Mixed_6e.branch_pool.bn.bias 192
# 	 AuxLogits.conv0.conv.weight 128
# 	 AuxLogits.conv0.bn.weight 128
# 	 AuxLogits.conv0.bn.bias 128
# 	 AuxLogits.conv1.conv.weight 768
# 	 AuxLogits.conv1.bn.weight 768
# 	 AuxLogits.conv1.bn.bias 768
# 	 AuxLogits.fc.weight 80
# 	 AuxLogits.fc.bias 80
# 	 Mixed_7a.branch3x3_1.conv.weight 192
# 	 Mixed_7a.branch3x3_1.bn.weight 192
# 	 Mixed_7a.branch3x3_1.bn.bias 192
# 	 Mixed_7a.branch3x3_2.conv.weight 320
# 	 Mixed_7a.branch3x3_2.bn.weight 320
# 	 Mixed_7a.branch3x3_2.bn.bias 320
# 	 Mixed_7a.branch7x7x3_1.conv.weight 192
# 	 Mixed_7a.branch7x7x3_1.bn.weight 192
# 	 Mixed_7a.branch7x7x3_1.bn.bias 192
# 	 Mixed_7a.branch7x7x3_2.conv.weight 192
# 	 Mixed_7a.branch7x7x3_2.bn.weight 192
# 	 Mixed_7a.branch7x7x3_2.bn.bias 192
# 	 Mixed_7a.branch7x7x3_3.conv.weight 192
# 	 Mixed_7a.branch7x7x3_3.bn.weight 192
# 	 Mixed_7a.branch7x7x3_3.bn.bias 192
# 	 Mixed_7a.branch7x7x3_4.conv.weight 192
# 	 Mixed_7a.branch7x7x3_4.bn.weight 192
# 	 Mixed_7a.branch7x7x3_4.bn.bias 192
# 	 Mixed_7b.branch1x1.conv.weight 320
# 	 Mixed_7b.branch1x1.bn.weight 320
# 	 Mixed_7b.branch1x1.bn.bias 320
# 	 Mixed_7b.branch3x3_1.conv.weight 384
# 	 Mixed_7b.branch3x3_1.bn.weight 384
# 	 Mixed_7b.branch3x3_1.bn.bias 384
# 	 Mixed_7b.branch3x3_2a.conv.weight 384
# 	 Mixed_7b.branch3x3_2a.bn.weight 384
# 	 Mixed_7b.branch3x3_2a.bn.bias 384
# 	 Mixed_7b.branch3x3_2b.conv.weight 384
# 	 Mixed_7b.branch3x3_2b.bn.weight 384
# 	 Mixed_7b.branch3x3_2b.bn.bias 384
# 	 Mixed_7b.branch3x3dbl_1.conv.weight 448
# 	 Mixed_7b.branch3x3dbl_1.bn.weight 448
# 	 Mixed_7b.branch3x3dbl_1.bn.bias 448
# 	 Mixed_7b.branch3x3dbl_2.conv.weight 384
# 	 Mixed_7b.branch3x3dbl_2.bn.weight 384
# 	 Mixed_7b.branch3x3dbl_2.bn.bias 384
# 	 Mixed_7b.branch3x3dbl_3a.conv.weight 384
# 	 Mixed_7b.branch3x3dbl_3a.bn.weight 384
# 	 Mixed_7b.branch3x3dbl_3a.bn.bias 384
# 	 Mixed_7b.branch3x3dbl_3b.conv.weight 384
# 	 Mixed_7b.branch3x3dbl_3b.bn.weight 384
# 	 Mixed_7b.branch3x3dbl_3b.bn.bias 384
# 	 Mixed_7b.branch_pool.conv.weight 192
# 	 Mixed_7b.branch_pool.bn.weight 192
# 	 Mixed_7b.branch_pool.bn.bias 192
# 	 Mixed_7c.branch1x1.conv.weight 320
# 	 Mixed_7c.branch1x1.bn.weight 320
# 	 Mixed_7c.branch1x1.bn.bias 320
# 	 Mixed_7c.branch3x3_1.conv.weight 384
# 	 Mixed_7c.branch3x3_1.bn.weight 384
# 	 Mixed_7c.branch3x3_1.bn.bias 384
# 	 Mixed_7c.branch3x3_2a.conv.weight 384
# 	 Mixed_7c.branch3x3_2a.bn.weight 384
# 	 Mixed_7c.branch3x3_2a.bn.bias 384
# 	 Mixed_7c.branch3x3_2b.conv.weight 384
# 	 Mixed_7c.branch3x3_2b.bn.weight 384
# 	 Mixed_7c.branch3x3_2b.bn.bias 384
# 	 Mixed_7c.branch3x3dbl_1.conv.weight 448
# 	 Mixed_7c.branch3x3dbl_1.bn.weight 448
# 	 Mixed_7c.branch3x3dbl_1.bn.bias 448
# 	 Mixed_7c.branch3x3dbl_2.conv.weight 384
# 	 Mixed_7c.branch3x3dbl_2.bn.weight 384
# 	 Mixed_7c.branch3x3dbl_2.bn.bias 384
# 	 Mixed_7c.branch3x3dbl_3a.conv.weight 384
# 	 Mixed_7c.branch3x3dbl_3a.bn.weight 384
# 	 Mixed_7c.branch3x3dbl_3a.bn.bias 384
# 	 Mixed_7c.branch3x3dbl_3b.conv.weight 384
# 	 Mixed_7c.branch3x3dbl_3b.bn.weight 384
# 	 Mixed_7c.branch3x3dbl_3b.bn.bias 384
# 	 Mixed_7c.branch_pool.conv.weight 192
# 	 Mixed_7c.branch_pool.bn.weight 192
# 	 Mixed_7c.branch_pool.bn.bias 192
# 	 fc.weight 80
# 	 fc.bias 80
# CUDA is available!  Training on GPU ...
# Epoch 0/149
# ----------
# train Loss: 8.5044 Acc: 0.0118
# val Loss: 4.4381 Acc: 0.0094
# Time elapsed: 62m 39s
# ----------
# Epoch 1/149
# ----------
# train Loss: 8.1894 Acc: 0.0123
# val Loss: 4.4885 Acc: 0.0100
# Time elapsed: 64m 21s
# ----------
# Epoch 2/149
# ----------
# train Loss: 7.9735 Acc: 0.0145
# val Loss: 4.3769 Acc: 0.0157
# Time elapsed: 66m 2s
# ----------
# Epoch 3/149
# ----------
# train Loss: 7.7437 Acc: 0.0183
# val Loss: 4.2467 Acc: 0.0169
# Time elapsed: 67m 44s
# ----------
# Epoch 4/149
# ----------
# train Loss: 7.6129 Acc: 0.0225
# val Loss: 4.1568 Acc: 0.0188
# Time elapsed: 69m 26s
# ----------
# Epoch 5/149
# ----------
# train Loss: 7.5516 Acc: 0.0220
# val Loss: 4.1389 Acc: 0.0219
# Time elapsed: 71m 8s
# ----------
# Epoch 6/149
# ----------
# train Loss: 7.5047 Acc: 0.0249
# val Loss: 4.2227 Acc: 0.0219
# Time elapsed: 72m 50s
# ----------
# Epoch 7/149
# ----------
# train Loss: 7.4198 Acc: 0.0274
# val Loss: 4.1932 Acc: 0.0251
# Time elapsed: 74m 32s
# ----------
# Epoch 8/149
# ----------
# train Loss: 7.3565 Acc: 0.0319
# val Loss: 4.1517 Acc: 0.0326
# Time elapsed: 76m 14s
# ----------
# Epoch 9/149
# ----------
# train Loss: 7.3235 Acc: 0.0361
# val Loss: 4.0489 Acc: 0.0363
# Time elapsed: 77m 57s
# ----------
# Epoch 10/149
# ----------
# train Loss: 7.2556 Acc: 0.0419
# val Loss: 4.0776 Acc: 0.0420
# Time elapsed: 79m 39s
# ----------
# Epoch 11/149
# ----------
# train Loss: 7.1852 Acc: 0.0394
# val Loss: 4.0077 Acc: 0.0420
# Time elapsed: 81m 21s
# ----------
# Epoch 12/149
# ----------
# train Loss: 7.1223 Acc: 0.0442
# val Loss: 4.2350 Acc: 0.0426
# Time elapsed: 83m 3s
# ----------
# Epoch 13/149
# ----------
# train Loss: 7.0778 Acc: 0.0421
# val Loss: 4.0206 Acc: 0.0432
# Time elapsed: 84m 45s
# ----------
# Epoch 14/149
# ----------
# train Loss: 7.0773 Acc: 0.0476
# val Loss: 3.9498 Acc: 0.0476
# Time elapsed: 86m 27s
# ----------
# Epoch 15/149
# ----------
# train Loss: 7.0092 Acc: 0.0426
# val Loss: 3.9437 Acc: 0.0533
# Time elapsed: 88m 9s
# ----------
# Epoch 16/149
# ----------
# train Loss: 6.9671 Acc: 0.0485
# val Loss: 3.8948 Acc: 0.0539
# Time elapsed: 89m 51s
# ----------
# Epoch 17/149
# ----------
# train Loss: 6.8954 Acc: 0.0481
# val Loss: 3.8231 Acc: 0.0520
# Time elapsed: 91m 34s
# ----------
# Epoch 18/149
# ----------
# train Loss: 6.8500 Acc: 0.0601
# val Loss: 4.7827 Acc: 0.0370
# Time elapsed: 93m 16s
# ----------
# Epoch 19/149
# ----------
# train Loss: 6.8573 Acc: 0.0573
# val Loss: 3.7930 Acc: 0.0539
# Time elapsed: 94m 59s
# ----------
# Epoch 20/149
# ----------
# train Loss: 6.7767 Acc: 0.0596
# val Loss: 4.5841 Acc: 0.0426
# Time elapsed: 96m 42s
# ----------
# Epoch 21/149
# ----------
# train Loss: 6.7214 Acc: 0.0610
# val Loss: 3.8409 Acc: 0.0683
# Time elapsed: 98m 24s
# ----------
# Epoch 22/149
# ----------
# train Loss: 6.6596 Acc: 0.0687
# val Loss: 3.7804 Acc: 0.0489
# Time elapsed: 100m 7s
# ----------
# Epoch 23/149
# ----------
# train Loss: 6.6280 Acc: 0.0598
# val Loss: 3.7208 Acc: 0.0564
# Time elapsed: 101m 50s
# ----------
# Epoch 24/149
# ----------
# train Loss: 6.5823 Acc: 0.0660
# val Loss: 3.8416 Acc: 0.0526
# Time elapsed: 103m 33s
# ----------
# Epoch 25/149
# ----------
# train Loss: 6.5641 Acc: 0.0707
# val Loss: 3.6491 Acc: 0.0633
# Time elapsed: 105m 16s
# ----------
# Epoch 26/149
# ----------
# train Loss: 6.4974 Acc: 0.0678
# val Loss: 3.7945 Acc: 0.0589
# Time elapsed: 106m 59s
# ----------
# Epoch 27/149
# ----------
# train Loss: 6.4345 Acc: 0.0791
# val Loss: 3.7177 Acc: 0.0758
# Time elapsed: 108m 41s
# ----------
# Epoch 28/149
# ----------
# train Loss: 6.4276 Acc: 0.0719
# val Loss: 3.6139 Acc: 0.0865
# Time elapsed: 110m 24s
# ----------
# Epoch 29/149
# ----------
# train Loss: 6.3713 Acc: 0.0795
# val Loss: 7.1008 Acc: 0.0520
# Time elapsed: 112m 7s
# ----------
# Epoch 30/149
# ----------
# train Loss: 6.4365 Acc: 0.0702
# val Loss: 3.6421 Acc: 0.0783
# Time elapsed: 113m 49s
# ----------
# Epoch 31/149
# ----------
# train Loss: 6.3148 Acc: 0.0757
# val Loss: 3.8565 Acc: 0.0714
# Time elapsed: 115m 32s
# ----------
# Epoch 32/149
# ----------
# train Loss: 6.2785 Acc: 0.0861
# val Loss: 3.6085 Acc: 0.0896
# Time elapsed: 117m 15s
# ----------
# Epoch 33/149
# ----------
# train Loss: 6.2306 Acc: 0.0845
# val Loss: 3.5981 Acc: 0.0796
# Time elapsed: 118m 57s
# ----------
# Epoch 34/149
# ----------
# train Loss: 6.1726 Acc: 0.0836
# val Loss: 3.6280 Acc: 0.0764
# Time elapsed: 120m 40s
# ----------
# Epoch 35/149
# ----------
# train Loss: 6.1608 Acc: 0.0880
# val Loss: 3.6493 Acc: 0.0996
# Time elapsed: 122m 23s
# ----------
# Epoch 36/149
# ----------
# train Loss: 6.0866 Acc: 0.0954
# val Loss: 3.6609 Acc: 0.0802
# Time elapsed: 124m 5s
# ----------
# Epoch 37/149
# ----------
# train Loss: 6.0335 Acc: 0.1018
# val Loss: 4.1124 Acc: 0.0639
# Time elapsed: 125m 48s
# ----------
# Epoch 38/149
# ----------
# train Loss: 5.9962 Acc: 0.1047
# val Loss: 3.6045 Acc: 0.0846
# Time elapsed: 127m 30s
# ----------
# Epoch 39/149
# ----------
# train Loss: 5.9878 Acc: 0.1020
# val Loss: 3.5335 Acc: 0.1071
# Time elapsed: 129m 14s
# ----------
# Epoch 40/149
# ----------
# train Loss: 5.9129 Acc: 0.1077
# val Loss: 3.8199 Acc: 0.0902
# Time elapsed: 130m 56s
# ----------
# Epoch 41/149
# ----------
# train Loss: 5.9033 Acc: 0.1122
# val Loss: 3.5406 Acc: 0.0940
# Time elapsed: 132m 39s
# ----------
# Epoch 42/149
# ----------
# train Loss: 5.8281 Acc: 0.1110
# val Loss: 4.8196 Acc: 0.1003
# Time elapsed: 134m 22s
# ----------
# Epoch 43/149
# ----------
# train Loss: 5.7783 Acc: 0.1158
# val Loss: 3.6328 Acc: 0.0909
# Time elapsed: 136m 5s
# ----------
# Epoch 44/149
# ----------
# train Loss: 5.8034 Acc: 0.1212
# val Loss: 3.3859 Acc: 0.1153
# Time elapsed: 137m 48s
# ----------
# Epoch 45/149
# ----------
# train Loss: 5.7615 Acc: 0.1231
# val Loss: 3.7041 Acc: 0.0902
# Time elapsed: 139m 31s
# ----------
# Epoch 46/149
# ----------
# train Loss: 5.6892 Acc: 0.1269
# val Loss: 3.4397 Acc: 0.1053
# Time elapsed: 141m 13s
# ----------
# Epoch 47/149
# ----------
# train Loss: 5.7136 Acc: 0.1224
# val Loss: 4.3516 Acc: 0.0827
# Time elapsed: 142m 56s
# ----------
# Epoch 48/149
# ----------
# train Loss: 5.6793 Acc: 0.1136
# val Loss: 3.6489 Acc: 0.0984
# Time elapsed: 144m 39s
# ----------
# Epoch 49/149
# ----------
# train Loss: 5.5896 Acc: 0.1251
# val Loss: 3.3644 Acc: 0.1115
# Time elapsed: 146m 22s
# ----------
# Epoch 50/149
# ----------
# train Loss: 5.5730 Acc: 0.1290
# val Loss: 3.6087 Acc: 0.1109
# Time elapsed: 148m 5s
# ----------
# Epoch 51/149
# ----------
# train Loss: 5.5306 Acc: 0.1353
# val Loss: 3.4110 Acc: 0.1197
# Time elapsed: 149m 48s
# ----------
# Epoch 52/149
# ----------
# train Loss: 5.4745 Acc: 0.1319
# val Loss: 3.3755 Acc: 0.1159
# Time elapsed: 151m 31s
# ----------
# Epoch 53/149
# ----------
# train Loss: 5.4112 Acc: 0.1365
# val Loss: 3.4765 Acc: 0.1071
# Time elapsed: 153m 13s
# ----------
# Epoch 54/149
# ----------
# train Loss: 5.4516 Acc: 0.1362
# val Loss: 3.4392 Acc: 0.1297
# Time elapsed: 154m 57s
# ----------
# Epoch 55/149
# ----------
# train Loss: 5.3732 Acc: 0.1398
# val Loss: 3.8010 Acc: 0.0977
# Time elapsed: 156m 39s
# ----------
# Epoch 56/149
# ----------
# train Loss: 5.3022 Acc: 0.1389
# val Loss: 3.3529 Acc: 0.1159
# Time elapsed: 158m 22s
# ----------
# Epoch 57/149
# ----------
# train Loss: 5.3129 Acc: 0.1421
# val Loss: 3.3758 Acc: 0.1203
# Time elapsed: 160m 5s
# ----------
# Epoch 58/149
# ----------
# train Loss: 5.2477 Acc: 0.1464
# val Loss: 3.3690 Acc: 0.1266
# Time elapsed: 161m 48s
# ----------
# Epoch 59/149
# ----------
# train Loss: 5.2120 Acc: 0.1507
# val Loss: 3.4099 Acc: 0.1284
# Time elapsed: 163m 31s
# ----------
# Epoch 60/149
# ----------
# train Loss: 5.1857 Acc: 0.1480
# val Loss: 3.2447 Acc: 0.1328
# Time elapsed: 165m 14s
# ----------
# Epoch 61/149
# ----------
# train Loss: 5.1596 Acc: 0.1509
# val Loss: 3.3159 Acc: 0.1209
# Time elapsed: 166m 57s
# ----------
# Epoch 62/149
# ----------
# train Loss: 5.0695 Acc: 0.1614
# val Loss: 3.3677 Acc: 0.1216
# Time elapsed: 168m 40s
# ----------
# Epoch 63/149
# ----------
# train Loss: 5.0819 Acc: 0.1593
# val Loss: 3.4455 Acc: 0.1222
# Time elapsed: 170m 22s
# ----------
# Epoch 64/149
# ----------
# train Loss: 5.0106 Acc: 0.1657
# val Loss: 3.2291 Acc: 0.1479
# Time elapsed: 172m 5s
# ----------
# Epoch 65/149
# ----------
# train Loss: 5.0471 Acc: 0.1612
# val Loss: 3.2622 Acc: 0.1247
# Time elapsed: 173m 48s
# ----------
# Epoch 66/149
# ----------
# train Loss: 4.9472 Acc: 0.1691
# val Loss: 3.3478 Acc: 0.1272
# Time elapsed: 175m 31s
# ----------
# Epoch 67/149
# ----------
# train Loss: 4.9259 Acc: 0.1623
# val Loss: 3.2467 Acc: 0.1404
# Time elapsed: 177m 15s
# ----------
# Epoch 68/149
# ----------
# train Loss: 4.9188 Acc: 0.1677
# val Loss: 3.5181 Acc: 0.1372
# Time elapsed: 178m 58s
# ----------
# Epoch 69/149
# ----------
# train Loss: 4.8557 Acc: 0.1730
# val Loss: 3.3936 Acc: 0.1322
# Time elapsed: 180m 40s
# ----------
# Epoch 70/149
# ----------
# train Loss: 4.8523 Acc: 0.1750
# val Loss: 3.4021 Acc: 0.1422
# Time elapsed: 182m 23s
# ----------
# Epoch 71/149
# ----------
# train Loss: 4.8024 Acc: 0.1756
# val Loss: 3.3129 Acc: 0.1391
# Time elapsed: 184m 6s
# ----------
# Epoch 72/149
# ----------
# train Loss: 4.7533 Acc: 0.1845
# val Loss: 3.2536 Acc: 0.1410
# Time elapsed: 185m 48s
# ----------
# Epoch 73/149
# ----------
# train Loss: 4.7607 Acc: 0.1784
# val Loss: 3.2923 Acc: 0.1510
# Time elapsed: 187m 32s
# ----------
# Epoch 74/149
# ----------
# train Loss: 4.6726 Acc: 0.1788
# val Loss: 3.4105 Acc: 0.1429
# Time elapsed: 189m 14s
# ----------
# Epoch 75/149
# ----------
# ////// NEW LEARNING RATE: 0.0025 //////
# train Loss: 4.4371 Acc: 0.2013
# val Loss: 3.1701 Acc: 0.1635
# Time elapsed: 190m 57s
# ----------
# Epoch 76/149
# ----------
# train Loss: 4.3371 Acc: 0.2092
# val Loss: 3.1671 Acc: 0.1698
# Time elapsed: 192m 40s
# ----------
# Epoch 77/149
# ----------
# train Loss: 4.3274 Acc: 0.2133
# val Loss: 3.2211 Acc: 0.1548
# Time elapsed: 194m 23s
# ----------
# Epoch 78/149
# ----------
# train Loss: 4.2153 Acc: 0.2199
# val Loss: 3.2290 Acc: 0.1353
# Time elapsed: 196m 5s
# ----------
# Epoch 79/149
# ----------
# train Loss: 4.2445 Acc: 0.2230
# val Loss: 3.2357 Acc: 0.1504
# Time elapsed: 197m 48s
# ----------
# Epoch 80/149
# ----------
# train Loss: 4.1856 Acc: 0.2244
# val Loss: 3.2448 Acc: 0.1429
# Time elapsed: 199m 30s
# ----------
# Epoch 81/149
# ----------
# train Loss: 4.1406 Acc: 0.2249
# val Loss: 3.2608 Acc: 0.1435
# Time elapsed: 201m 13s
# ----------
# Epoch 82/149
# ----------
# train Loss: 4.1045 Acc: 0.2300
# val Loss: 3.2208 Acc: 0.1679
# Time elapsed: 202m 56s
# ----------
# Epoch 83/149
# ----------
# train Loss: 4.0998 Acc: 0.2267
# val Loss: 3.1684 Acc: 0.1654
# Time elapsed: 204m 38s
# ----------
# Epoch 84/149
# ----------
# train Loss: 4.1355 Acc: 0.2260
# val Loss: 3.2470 Acc: 0.1573
# Time elapsed: 206m 21s
# ----------
# Epoch 85/149
# ----------
# train Loss: 4.0501 Acc: 0.2366
# val Loss: 3.2112 Acc: 0.1591
# Time elapsed: 208m 4s
# ----------
# Epoch 86/149
# ----------
# train Loss: 4.0063 Acc: 0.2453
# val Loss: 3.1754 Acc: 0.1792
# Time elapsed: 209m 47s
# ----------
# Epoch 87/149
# ----------
# train Loss: 4.0396 Acc: 0.2480
# val Loss: 3.4372 Acc: 0.1579
# Time elapsed: 211m 29s
# ----------
# Epoch 88/149
# ----------
# train Loss: 4.0016 Acc: 0.2445
# val Loss: 3.2533 Acc: 0.1604
# Time elapsed: 213m 12s
# ----------
# Epoch 89/149
# ----------
# train Loss: 3.9246 Acc: 0.2453
# val Loss: 3.2068 Acc: 0.1604
# Time elapsed: 214m 55s
# ----------
# Epoch 90/149
# ----------
# train Loss: 3.9345 Acc: 0.2521
# val Loss: 3.2765 Acc: 0.1660
# Time elapsed: 216m 38s
# ----------
# Epoch 91/149
# ----------
# train Loss: 3.8631 Acc: 0.2564
# val Loss: 3.1989 Acc: 0.1873
# Time elapsed: 218m 21s
# ----------
# Epoch 92/149
# ----------
# train Loss: 3.8534 Acc: 0.2586
# val Loss: 3.3782 Acc: 0.1779
# Time elapsed: 220m 3s
# ----------
# Epoch 93/149
# ----------
# train Loss: 3.8076 Acc: 0.2706
# val Loss: 3.2899 Acc: 0.1692
# Time elapsed: 221m 46s
# ----------
# Epoch 94/149
# ----------
# train Loss: 3.8264 Acc: 0.2706
# val Loss: 3.3680 Acc: 0.1579
# Time elapsed: 223m 29s
# ----------
# Epoch 95/149
# ----------
# train Loss: 3.8199 Acc: 0.2792
# val Loss: 3.3963 Acc: 0.1560
# Time elapsed: 225m 12s
# ----------
# Epoch 96/149
# ----------
# train Loss: 3.7807 Acc: 0.2722
# val Loss: 3.3060 Acc: 0.1717
# Time elapsed: 226m 55s
# ----------
# Epoch 97/149
# ----------
# train Loss: 3.7304 Acc: 0.2740
# val Loss: 3.3378 Acc: 0.1754
# Time elapsed: 228m 38s
# ----------
# Epoch 98/149
# ----------
# train Loss: 3.7405 Acc: 0.2738
# val Loss: 3.1956 Acc: 0.1823
# Time elapsed: 230m 20s
# ----------
# Epoch 99/149
# ----------
# train Loss: 3.7268 Acc: 0.2815
# val Loss: 3.2774 Acc: 0.1604
# Time elapsed: 232m 3s
# ----------
# Epoch 100/149
# ----------
# train Loss: 3.6801 Acc: 0.2861
# val Loss: 3.4034 Acc: 0.1660
# Time elapsed: 233m 45s
# ----------
# Epoch 101/149
# ----------
# train Loss: 3.6932 Acc: 0.2806
# val Loss: 3.3857 Acc: 0.1579
# Time elapsed: 235m 28s
# ----------
# Epoch 102/149
# ----------
# train Loss: 3.6611 Acc: 0.2944
# val Loss: 3.2784 Acc: 0.1767
# Time elapsed: 237m 12s
# ----------
# Epoch 103/149
# ----------
# train Loss: 3.6160 Acc: 0.2951
# val Loss: 3.5380 Acc: 0.1736
# Time elapsed: 238m 55s
# ----------
# Epoch 104/149
# ----------
# train Loss: 3.5691 Acc: 0.3026
# val Loss: 3.5391 Acc: 0.1742
# Time elapsed: 240m 38s
# ----------
# Epoch 105/149
# ----------
# train Loss: 3.5580 Acc: 0.2965
# val Loss: 3.5909 Acc: 0.1623
# Time elapsed: 242m 21s
# ----------
# Epoch 106/149
# ----------
# train Loss: 3.5980 Acc: 0.3028
# val Loss: 3.4194 Acc: 0.1723
# Time elapsed: 244m 4s
# ----------
# Epoch 107/149
# ----------
# train Loss: 3.5232 Acc: 0.3092
# val Loss: 3.3544 Acc: 0.1792
# Time elapsed: 245m 47s
# ----------
# Epoch 108/149
# ----------
# train Loss: 3.4879 Acc: 0.3130
# val Loss: 3.3728 Acc: 0.1767
# Time elapsed: 247m 30s
# ----------
# Epoch 109/149
# ----------
# train Loss: 3.4654 Acc: 0.3151
# val Loss: 3.3597 Acc: 0.1792
# Time elapsed: 249m 13s
# ----------
# Epoch 110/149
# ----------
# train Loss: 3.4483 Acc: 0.3243
# val Loss: 3.7248 Acc: 0.1629
# Time elapsed: 250m 55s
# ----------
# Epoch 111/149
# ----------
# train Loss: 3.4490 Acc: 0.3268
# val Loss: 3.4551 Acc: 0.1786
# Time elapsed: 252m 39s
# ----------
# Epoch 112/149
# ----------
# train Loss: 3.4096 Acc: 0.3293
# val Loss: 3.4466 Acc: 0.1692
# Time elapsed: 254m 22s
# ----------
# Epoch 113/149
# ----------
# train Loss: 3.4189 Acc: 0.3336
# val Loss: 3.4557 Acc: 0.1811
# Time elapsed: 256m 5s
# ----------
# Epoch 114/149
# ----------
# train Loss: 3.3502 Acc: 0.3336
# val Loss: 3.4399 Acc: 0.1604
# Time elapsed: 257m 48s
# ----------
# Epoch 115/149
# ----------
# train Loss: 3.2185 Acc: 0.3499
# val Loss: 3.7706 Acc: 0.1548
# Time elapsed: 259m 31s
# ----------
# Epoch 116/149
# ----------
# train Loss: 3.2884 Acc: 0.3488
# val Loss: 3.7428 Acc: 0.1736
# Time elapsed: 261m 15s
# ----------
# Epoch 117/149
# ----------
# train Loss: 3.2622 Acc: 0.3601
# val Loss: 3.8604 Acc: 0.1786
# Time elapsed: 262m 58s
# ----------
# Epoch 118/149
# ----------
# train Loss: 3.3344 Acc: 0.3452
# val Loss: 3.6790 Acc: 0.1773
# Time elapsed: 264m 41s
# ----------
# Epoch 119/149
# ----------
# train Loss: 3.2392 Acc: 0.3570
# val Loss: 3.4863 Acc: 0.1848
# Time elapsed: 266m 24s
# ----------
# Epoch 120/149
# ----------
# train Loss: 3.2396 Acc: 0.3576
# val Loss: 3.5126 Acc: 0.1817
# Time elapsed: 268m 7s
# ----------
# Epoch 121/149
# ----------
# train Loss: 3.2352 Acc: 0.3518
# val Loss: 3.4607 Acc: 0.1842
# Time elapsed: 269m 50s
# ----------
# Epoch 122/149
# ----------
# train Loss: 3.2511 Acc: 0.3667
# val Loss: 3.6258 Acc: 0.1917
# Time elapsed: 271m 33s
# ----------
# Epoch 123/149
# ----------
# train Loss: 3.2160 Acc: 0.3644
# val Loss: 3.7675 Acc: 0.1560
# Time elapsed: 273m 16s
# ----------
# Epoch 124/149
# ----------
# train Loss: 3.0792 Acc: 0.3921
# val Loss: 3.8158 Acc: 0.1811
# Time elapsed: 274m 59s
# ----------
# Epoch 125/149
# ----------
# train Loss: 3.1307 Acc: 0.3860
# val Loss: 3.7749 Acc: 0.1830
# Time elapsed: 276m 42s
# ----------
# Epoch 126/149
# ----------
# train Loss: 3.1383 Acc: 0.3826
# val Loss: 3.8745 Acc: 0.1817
# Time elapsed: 278m 25s
# ----------
# Epoch 127/149
# ----------
# train Loss: 3.0430 Acc: 0.3919
# val Loss: 3.6826 Acc: 0.1836
# Time elapsed: 280m 8s
# ----------
# Epoch 128/149
# ----------
# train Loss: 3.1122 Acc: 0.3846
# val Loss: 3.6756 Acc: 0.1748
# Time elapsed: 281m 51s
# ----------
# Epoch 129/149
# ----------
# train Loss: 3.0106 Acc: 0.4066
# val Loss: 3.7132 Acc: 0.1591
# Time elapsed: 283m 34s
# ----------
# Epoch 130/149
# ----------
# train Loss: 3.0153 Acc: 0.4014
# val Loss: 3.7784 Acc: 0.1761
# Time elapsed: 285m 18s
# ----------
# Epoch 131/149
# ----------
# train Loss: 3.0377 Acc: 0.3996
# val Loss: 3.6412 Acc: 0.1924
# Time elapsed: 287m 1s
# ----------
# Epoch 132/149
# ----------
# train Loss: 3.0151 Acc: 0.4046
# val Loss: 3.7592 Acc: 0.1767
# Time elapsed: 288m 44s
# ----------
# Epoch 133/149
# ----------
# train Loss: 2.9645 Acc: 0.4184
# val Loss: 3.7734 Acc: 0.1798
# Time elapsed: 290m 27s
# ----------
# Epoch 134/149
# ----------
# train Loss: 2.9567 Acc: 0.4236
# val Loss: 3.6835 Acc: 0.1692
# Time elapsed: 292m 9s
# ----------
# Epoch 135/149
# ----------
# train Loss: 2.9168 Acc: 0.4282
# val Loss: 3.9822 Acc: 0.1754
# Time elapsed: 293m 52s
# ----------
# Epoch 136/149
# ----------
# train Loss: 2.9003 Acc: 0.4331
# val Loss: 3.9190 Acc: 0.1779
# Time elapsed: 295m 35s
# ----------
# Epoch 137/149
# ----------
# train Loss: 2.8917 Acc: 0.4358
# val Loss: 3.7279 Acc: 0.1898
# Time elapsed: 297m 18s
# ----------
# Epoch 138/149
# ----------
# train Loss: 2.8739 Acc: 0.4358
# val Loss: 3.9260 Acc: 0.1773
# Time elapsed: 299m 2s
# ----------
# Epoch 139/149
# ----------
# train Loss: 2.8080 Acc: 0.4440
# val Loss: 3.9995 Acc: 0.1748
# Time elapsed: 300m 44s
# ----------
# Epoch 140/149
# ----------
# train Loss: 2.8238 Acc: 0.4442
# val Loss: 4.0434 Acc: 0.1685
# Time elapsed: 302m 28s
# ----------
# Epoch 141/149
# ----------
# train Loss: 2.8952 Acc: 0.4340
# val Loss: 3.9537 Acc: 0.1892
# Time elapsed: 304m 11s
# ----------
# Epoch 142/149
# ----------
# train Loss: 2.7694 Acc: 0.4579
# val Loss: 4.0011 Acc: 0.1848
# Time elapsed: 305m 54s
# ----------
# Epoch 143/149
# ----------
# train Loss: 2.6933 Acc: 0.4707
# val Loss: 3.9093 Acc: 0.1936
# Time elapsed: 307m 37s
# ----------
# Epoch 144/149
# ----------
# train Loss: 2.7329 Acc: 0.4732
# val Loss: 3.8213 Acc: 0.1779
# Time elapsed: 309m 20s
# ----------
# Epoch 145/149
# ----------
# train Loss: 2.7462 Acc: 0.4694
# val Loss: 4.3017 Acc: 0.1654
# Time elapsed: 311m 4s
# ----------
# Epoch 146/149
# ----------
# train Loss: 2.7231 Acc: 0.4708
# val Loss: 4.3459 Acc: 0.1654
# Time elapsed: 312m 46s
# ----------
# Epoch 147/149
# ----------
# train Loss: 2.6546 Acc: 0.4807
# val Loss: 4.1587 Acc: 0.1591
# Time elapsed: 314m 29s
# ----------
# Epoch 148/149
# ----------
# train Loss: 2.7171 Acc: 0.4773
# val Loss: 3.9207 Acc: 0.1886
# Time elapsed: 316m 12s
# ----------
# Epoch 149/149
# ----------
# train Loss: 2.5955 Acc: 0.4968
# val Loss: 4.1150 Acc: 0.1723
# Time elapsed: 317m 55s
# ----------
# Training complete in 317m 55s
# Best val Acc: 0.193609

# %% [markdown]
# ## Testing Model

# %%
def test_model(model, 
               datasets=image_datasets, 
               batch_size=256 ):
  
    since = time.time()
    dataloaders = {x: torch.utils.data.DataLoader(datasets[x], 
                                                  batch_size=batch_size, 
                                                  shuffle=True, 
                                                  num_workers=1) for x in ['test']}

    model.eval()   # Set model to evaluate mode
    running_corrects = 0

    # Iterate over data.
    for inputs, labels in dataloaders['test']:

        #############################################
        #To Enable GPU Usage
        if use_cuda and torch.cuda.is_available():
          inputs = inputs.cuda()
          labels = labels.cuda()
        #############################################

        # Get model outputs and calculate loss
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)

        # statistics
        running_corrects += torch.sum(preds == labels.data)

    test_acc = float(running_corrects) / len(dataloaders['test'].dataset)

    time_elapsed = time.time() - since
    print('Testing complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Test Acc: {:4f}'.format(test_acc))

    return

# %%
use_cuda = True
if use_cuda and torch.cuda.is_available():
  trained_model = trained_model.cuda()
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')


test_model(trained_model, datasets=image_datasets, batch_size=256)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-821eb1e19937> in <module>
#       1 use_cuda = True
#       2 if use_cuda and torch.cuda.is_available():
# ----> 3   trained_model = trained_model.cuda()
#       4   print('CUDA is available!  Training on GPU ...')
#       5 else:
#
# NameError: name 'trained_model' is not defined
