# %% [markdown]
# <a href="https://colab.research.google.com/github/NOBODIDI/APS360_GeoGuessr_NN/blob/main/Training_Primary_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Useful Links
#
# * Pytorch model: https://pytorch.org/vision/stable/models/generated/torchvision.models.googlenet.html#torchvision.models.googlenet
# *   https://pytorch.org/hub/pytorch_vision_googlenet/
# *   Background info: https://cs231n.github.io/transfer-learning/
# *   https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html
# * Finetuning: https://pytorch.org/tutorials/beginner/finetuning_torchvision_models_tutorial.html

# %%
import torch
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
from PIL import Image
import os
import matplotlib.pyplot as plt
import shutil
import time
import copy

# %% [markdown]
# ### Loading in Data

# %% [markdown]
# #### Splitting up Data into train-val-test folders (DO NOT RUN)

# %%
# Splitting data
# Data Loading and Splitting

train_files_list = []
val_files_list = []
test_files_list = []
files_list = []

dataset_size = 7983
split = [0.7,0.2,0.1]

train_size = int(split[0]*dataset_size)
val_size = int(split[1]*dataset_size)
test_size = dataset_size - (train_size + val_size)
print("Train size:",train_size,"\nVal size:",val_size,"\nTest size:",test_size)

# Fixed PyTorch random seed for reproducible result
np.random.seed(1000)

indices = list(range(0,dataset_size))
train_indices = list(np.random.choice(indices, train_size, replace=False))
other_than_train_indices = list(set(indices) - set(train_indices))
val_indices = np.random.choice(other_than_train_indices, val_size, replace=False)
test_indices = list(set(other_than_train_indices)-set(val_indices))

old_path = "/content/drive/MyDrive/APS360 Project - Initial Dataset (1)"

for root, dirs, files in os.walk(old_path):
    for file in files:
        #all 
        
        if file.endswith(".png"):
            files_list.append(os.path.join(root, file))

#print images
#lets me count and print the amount of jpeg,jpg,pmg 
file_count = len(files_list)
print("We have:",file_count,"images")
 
split_files_list = [ [files_list[i] for i in train_indices], [files_list[i] for i in val_indices], [files_list[i] for i in test_indices] ]

destPaths = ['train','val','test']
root_path = "/content/drive/MyDrive/train_val_test_split"

for i in range(len(destPaths)):

  destPath = os.path.join(root_path,destPaths[i])
  # if destination dir does not exists, create it
  if os.path.isdir(destPath) == False:
          os.makedirs(destPath)

  # iterate over all random files and move them
  for file in split_files_list[i]:

    file_class = (file.split('/'))[-2]
    classPath = os.path.join(destPath,file_class)
    if os.path.isdir(classPath) == False:
          os.makedirs(classPath)

    # shutil.copy(file, classPath)
# Out:
# Train size: 5588
# Val size: 1596
# Test size: 799

# %% [markdown]
# #### Transforms

# %%
# Image preprocessing for INCEPTION V3

#preprocess = models.GoogLeNet_Weights.IMAGENET1K_V1.transforms
#preprocess = model.Inception_V3_Weights.IMAGENET1K_V1.transforms
# INCEPTION ---------------------------

# Data augmentation and normalization for training
# Just normalization for validation
input_size = 299
input_resize = 342

data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(input_size),
        # transforms.RandomHorizontalFlip(), # remove this 
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_resize),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
     'test': transforms.Compose([
        transforms.Resize(input_resize),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

# input_tensor = preprocess(input_image)
# input_batch = input_tensor.unsqueeze(0) # create a mini-batch as expected by the model

# %% [markdown]
# #### Datasets and Dataloaders

# %%
# Loading in Data
batch_size = 64
root_path = "/content/drive/MyDrive/train_val_test_split"
# Fixed PyTorch random seed for reproducible result
torch.manual_seed(1000)

# Create training and validation and test datasets
image_datasets = {x: torchvision.datasets.ImageFolder(os.path.join(root_path, x), 
                                                      data_transforms[x]) for x in ['train', 'val','test']}

classes = image_datasets['train'].classes
num_classes = len(classes)
print("Total dataset:",len(image_datasets['train'])+len(image_datasets['val'])+len(image_datasets['test']),"\n",
      "\tTrain size:",len(image_datasets['train']),"\n\tVal size:",len(image_datasets['val']),"\n\tTest size:",len(image_datasets['test']))
print("Number of classes:",num_classes)

# Create training and validation and test dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, 
                                                   shuffle=True, num_workers=1) for x in ['train', 'val','test']}
# Out:
# Total dataset: 7983
#  	Train size: 5588
# 	Val size: 1596
# 	Test size: 799
# Number of classes: 80

# %% [markdown]
# ### Visualizing sample data

# %%
# Visualize some sample data
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp[0].numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

# # obtain one batch of training images
images, labels = next(iter(dataloaders_dict['train']))
print("Images size:",images.shape)
print("Labels size:",labels.data)

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(10, 9))
for i in np.arange(20):
    ax = fig.add_subplot(4, 20/4, i+1, xticks=[], yticks=[])
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = images[i].numpy().transpose((1,2,0))
    image = std * image + mean
    image = np.clip(image, 0, 1)
    plt.imshow(image)
    ax.set_title(classes[labels[i]])
# Out:
# Images size: torch.Size([64, 3, 299, 299])
# Labels size: tensor([27, 24, 58, 13, 62, 16, 19, 77, 35, 39, 46,  7, 38, 21, 53,  8, 73, 41,
#         32, 75, 66, 35, 32, 32, 30, 43, 67,  7,  6, 27, 32, 39, 75, 44, 28, 58,
#         47, 27, 21,  5, 68,  1, 68, 71, 11, 78, 55, 76, 59, 16, 31,  7, 36, 28,
#         14,  1, 23, 66, 70, 42, 74, 23, 42, 60])

# %% [markdown]
# ## Model

# %% [markdown]
# ### Initializing InceptionV3

# %%
incepNet = models.inception_v3(weights='Inception_V3_Weights.IMAGENET1K_V1')
# Out:
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
#   0%|          | 0.00/104M [00:00<?, ?B/s]

# %%
# Freezing all the gradients of the model parameters (TRANSFER LEARNING)
for param in incepNet.parameters():
    param.requires_grad = False

# Changing the number of output features for the FC linear classifiers to 
# match the number of classes (80)

# Auxiliary Loss FC layer
num_aux_ftrs = incepNet.AuxLogits.fc.in_features
print("Auxliary loss features:",num_aux_ftrs)
incepNet.AuxLogits.fc = nn.Linear(num_aux_ftrs, num_classes)

# Final Loss FC layer
num_ftrs = incepNet.fc.in_features
print("Final loss features:",num_ftrs)
incepNet.fc = nn.Linear(num_ftrs,num_classes)

# Choosing which parameter gradients to optimize (only at the final FC layers)
print("Params to learn:")

params_to_update = []
for name,param in incepNet.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name,len(param))
# Out:
# Auxliary loss features: 768
# Final loss features: 2048
# Params to learn:
# 	 AuxLogits.fc.weight 80
# 	 AuxLogits.fc.bias 80
# 	 fc.weight 80
# 	 fc.bias 80

# %% [markdown]
# ### Training the Model

# %%
def init_model():
  incepNet = models.inception_v3(weights='Inception_V3_Weights.IMAGENET1K_V1')
  # Freezing all the gradients of the model parameters (TRANSFER LEARNING)
  for param in incepNet.parameters():
      param.requires_grad = False

  # Changing the number of output features for the FC linear classifiers to 
  # match the number of classes (80)
  # Auxiliary Loss FC layer
  num_aux_ftrs = incepNet.AuxLogits.fc.in_features
  incepNet.AuxLogits.fc = nn.Linear(num_aux_ftrs, num_classes)

  # Final Loss FC layer
  num_ftrs = incepNet.fc.in_features
  incepNet.fc = nn.Linear(num_ftrs,num_classes)

  # Choosing which parameter gradients to optimize (only at the final FC layers)
  params_to_update = []
  for name,param in incepNet.named_parameters():
      if param.requires_grad == True:
          params_to_update.append(param)
  return incepNet, params_to_update

# %%
# Training code modified from https://pytorch.org/tutorials/beginner/finetuning_torchvision_models_tutorial.html
def train_model(model, datasets, batch_size=64, learning_rate=1e-3, aux_coef=0.4, num_epochs=5):
    since = time.time()

    dataloaders = {x: torch.utils.data.DataLoader(datasets[x], 
                                                  batch_size=batch_size, 
                                                  shuffle=True, 
                                                  num_workers=1) for x in ['train', 'val']}

    # Observe that some parameters are being optimized
    optimizer = optim.Adam(params_to_update, lr=learning_rate)
    # Setup the loss fxn
    criterion = nn.CrossEntropyLoss()

    val_loss_history = []
    val_acc_history = []
    train_loss_history = []
    train_acc_history = []
    epochs = np.arange(0,num_epochs)

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        # start_epoch = time.time()
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:

                #############################################
                #To Enable GPU Usage
                if use_cuda and torch.cuda.is_available():
                  inputs = inputs.cuda()
                  labels = labels.cuda()
                #############################################

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    # Special case for the loss by summing the final output and the auxiliary output
                    #   but in testing inception because in training it has an auxiliary output. In train
                    #   mode we calculate  only consider the final output.
                    if phase == 'train':
                        # From https://discuss.pytorch.org/t/how-to-optimize-inception-model-with-auxiliary-classifiers/7958
                        outputs, aux_outputs = model(inputs)
                        loss1 = criterion(outputs, labels)
                        loss2 = criterion(aux_outputs, labels)
                        loss = loss1 + aux_coef*loss2
                    else:
                        outputs = model(inputs)
                        loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)
                    # preds = outputs.max(1, keepdim=True)[1]

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                # if (phase == 'val'):
                #   print(preds.shape())
                #   print(labels.data.shape())
                running_corrects += torch.sum(preds == labels.data)
                # running_corrects += preds.eq(labels.view_as(preds)).sum().item()
                # print('{} Running Loss: {:.4f} Running Acc: {:.4f}'.format(phase, running_loss, running_corrects))

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = float(running_corrects) / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'val':
                val_acc_history.append(epoch_acc)
                val_loss_history.append(epoch_loss)
            if phase == 'train':
                train_acc_history.append(epoch_acc)
                train_loss_history.append(epoch_loss)

        time_elapsed = time.time() - since
        print('Time elapsed: {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))    
        print('-' * 10)

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    plt.title("Training vs Validation Loss Curve")
    plt.plot(epochs, train_loss_history, label="Train")
    plt.plot(epochs, val_loss_history, label="Validation")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend(loc='best')
    plt.show()

    plt.title("Training vs Validation Accuracy Curve")
    plt.plot(epochs, train_acc_history, label="Train")
    plt.plot(epochs, val_acc_history, label="Validation")
    plt.xlabel("Epochs")
    plt.ylabel("Training Accuracy")
    plt.legend(loc='best')
    plt.show()

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, val_acc_history

# %% [markdown]
# ## Training Model

# %%
model, params_to_update = init_model()
use_cuda = True

if use_cuda and torch.cuda.is_available():
  model = model.cuda()
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')
# 512 
train_model(model, datasets=image_datasets, batch_size=256, learning_rate=1e-4, aux_coef=0.4, num_epochs=100)
# Out:
# CUDA is available!  Training on GPU ...
# Epoch 0/99
# ----------
# train Loss: 6.2090 Acc: 0.0127
# val Loss: 4.3899 Acc: 0.0138
# Time elapsed: 1m 40s
# ----------
# Epoch 1/99
# ----------
# train Loss: 6.1529 Acc: 0.0159
# val Loss: 4.3729 Acc: 0.0169
# Time elapsed: 3m 20s
# ----------
# Epoch 2/99
# ----------
# train Loss: 6.1123 Acc: 0.0170
# val Loss: 4.3590 Acc: 0.0188
# Time elapsed: 4m 59s
# ----------
# Epoch 3/99
# ----------
# train Loss: 6.0721 Acc: 0.0217
# val Loss: 4.3438 Acc: 0.0257
# Time elapsed: 6m 39s
# ----------
# Epoch 4/99
# ----------
# train Loss: 6.0410 Acc: 0.0231
# val Loss: 4.3291 Acc: 0.0294
# Time elapsed: 8m 20s
# ----------
# Epoch 5/99
# ----------
# train Loss: 6.0050 Acc: 0.0301
# val Loss: 4.3147 Acc: 0.0351
# Time elapsed: 10m 0s
# ----------
# Epoch 6/99
# ----------
# train Loss: 5.9777 Acc: 0.0335
# val Loss: 4.3007 Acc: 0.0376
# Time elapsed: 11m 39s
# ----------
# Epoch 7/99
# ----------
# train Loss: 5.9464 Acc: 0.0369
# val Loss: 4.2895 Acc: 0.0407
# Time elapsed: 13m 19s
# ----------
# Epoch 8/99
# ----------
# train Loss: 5.9218 Acc: 0.0351
# val Loss: 4.2786 Acc: 0.0445
# Time elapsed: 14m 59s
# ----------
# Epoch 9/99
# ----------

# %%
model, params_to_update = init_model()
use_cuda = True

if use_cuda and torch.cuda.is_available():
  model = model.cuda()
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')
# 512 
train_model(model, datasets=image_datasets, batch_size=256, learning_rate=1e-3, aux_coef=0.4, num_epochs=50)
# Out:
# CUDA is available!  Training on GPU ...
# Epoch 0/49
# ----------
# train Loss: 6.1545 Acc: 0.0165
# val Loss: 4.3040 Acc: 0.0414
# Epoch 1/49
# ----------
# train Loss: 5.8691 Acc: 0.0344
# val Loss: 4.2000 Acc: 0.0451
# Epoch 2/49
# ----------
# train Loss: 5.6721 Acc: 0.0565
# val Loss: 4.1364 Acc: 0.0551
# Epoch 3/49
# ----------
# train Loss: 5.5518 Acc: 0.0634
# val Loss: 4.0791 Acc: 0.0683
# Epoch 4/49
# ----------
# train Loss: 5.4270 Acc: 0.0821
# val Loss: 4.0339 Acc: 0.0695
# Epoch 5/49
# ----------
# train Loss: 5.3231 Acc: 0.0991
# val Loss: 3.9729 Acc: 0.0764
# Epoch 6/49
# ----------
# train Loss: 5.2473 Acc: 0.1018
# val Loss: 3.9250 Acc: 0.0802
# Epoch 7/49
# ----------
# train Loss: 5.2048 Acc: 0.1070
# val Loss: 3.9184 Acc: 0.0890
# Epoch 8/49
# ----------
# train Loss: 5.1316 Acc: 0.1176
# val Loss: 3.9051 Acc: 0.0821
# Epoch 9/49
# ----------
# train Loss: 5.0700 Acc: 0.1237
# val Loss: 3.8642 Acc: 0.0915
# Epoch 10/49
# ----------
# train Loss: 5.0275 Acc: 0.1271
# val Loss: 3.8595 Acc: 0.0846
# Epoch 11/49
# ----------
# train Loss: 4.9730 Acc: 0.1319
# val Loss: 3.8509 Acc: 0.0796
# Epoch 12/49
# ----------
# train Loss: 4.9615 Acc: 0.1315
# val Loss: 3.8117 Acc: 0.0877
# Epoch 13/49
# ----------
# train Loss: 4.9407 Acc: 0.1315
# val Loss: 3.8198 Acc: 0.0977
# Epoch 14/49
# ----------
# train Loss: 4.8901 Acc: 0.1457
# val Loss: 3.8039 Acc: 0.0934
# Epoch 15/49
# ----------
# train Loss: 4.8484 Acc: 0.1441
# val Loss: 3.7825 Acc: 0.0946
# Epoch 16/49
# ----------
# train Loss: 4.8325 Acc: 0.1584
# val Loss: 3.7739 Acc: 0.0965
# Epoch 17/49
# ----------
# train Loss: 4.8172 Acc: 0.1539
# val Loss: 3.7717 Acc: 0.0984
# Epoch 18/49
# ----------
# train Loss: 4.7907 Acc: 0.1594
# val Loss: 3.7890 Acc: 0.0934
# Epoch 19/49
# ----------
# train Loss: 4.7606 Acc: 0.1600
# val Loss: 3.7732 Acc: 0.0940
# Epoch 20/49
# ----------
# train Loss: 4.7358 Acc: 0.1625
# val Loss: 3.7474 Acc: 0.1103
# Epoch 21/49
# ----------
# train Loss: 4.7122 Acc: 0.1607
# val Loss: 3.7428 Acc: 0.1034
# Epoch 22/49
# ----------
# train Loss: 4.6951 Acc: 0.1630
# val Loss: 3.7515 Acc: 0.1053
# Epoch 23/49
# ----------
# train Loss: 4.6671 Acc: 0.1707
# val Loss: 3.7419 Acc: 0.1015
# Epoch 24/49
# ----------
# train Loss: 4.6690 Acc: 0.1714
# val Loss: 3.7434 Acc: 0.0990
# Epoch 25/49
# ----------
# train Loss: 4.6702 Acc: 0.1637
# val Loss: 3.7515 Acc: 0.0971
# Epoch 26/49
# ----------
# train Loss: 4.6636 Acc: 0.1691
# val Loss: 3.7405 Acc: 0.0990
# Epoch 27/49
# ----------
# train Loss: 4.6173 Acc: 0.1756
# val Loss: 3.7269 Acc: 0.1040
# Epoch 28/49
# ----------
# train Loss: 4.6307 Acc: 0.1772
# val Loss: 3.7391 Acc: 0.0952
# Epoch 29/49
# ----------
# train Loss: 4.6238 Acc: 0.1732
# val Loss: 3.7448 Acc: 0.1034
# Epoch 30/49
# ----------
# train Loss: 4.5952 Acc: 0.1671
# val Loss: 3.7234 Acc: 0.1034
# Epoch 31/49
# ----------
# train Loss: 4.5898 Acc: 0.1811
# val Loss: 3.7139 Acc: 0.1134
# Epoch 32/49
# ----------
# train Loss: 4.5731 Acc: 0.1827
# val Loss: 3.7206 Acc: 0.1028
# Epoch 33/49
# ----------
# train Loss: 4.5636 Acc: 0.1861
# val Loss: 3.7208 Acc: 0.1115
# Epoch 34/49
# ----------
# train Loss: 4.5508 Acc: 0.1892
# val Loss: 3.7136 Acc: 0.1103
# Epoch 35/49
# ----------
# train Loss: 4.5494 Acc: 0.1782
# val Loss: 3.7235 Acc: 0.1065
# Epoch 36/49
# ----------
# train Loss: 4.5343 Acc: 0.1866
# val Loss: 3.7204 Acc: 0.0996
# Epoch 37/49
# ----------
# train Loss: 4.5187 Acc: 0.1827
# val Loss: 3.7097 Acc: 0.1115
# Epoch 38/49
# ----------
# train Loss: 4.5035 Acc: 0.1917
# val Loss: 3.7142 Acc: 0.1090
# Epoch 39/49
# ----------
# train Loss: 4.5210 Acc: 0.1849
# val Loss: 3.7168 Acc: 0.1071
# Epoch 40/49
# ----------
# train Loss: 4.5120 Acc: 0.1874
# val Loss: 3.7244 Acc: 0.1071
# Epoch 41/49
# ----------
# train Loss: 4.4791 Acc: 0.1995
# val Loss: 3.7295 Acc: 0.1046
# Epoch 42/49
# ----------
# train Loss: 4.4812 Acc: 0.1936
# val Loss: 3.7103 Acc: 0.1084
# Epoch 43/49
# ----------
# train Loss: 4.4790 Acc: 0.1972
# val Loss: 3.7197 Acc: 0.0996
# Epoch 44/49
# ----------
# train Loss: 4.4588 Acc: 0.1960
# val Loss: 3.7360 Acc: 0.1028
# Epoch 45/49
# ----------
# train Loss: 4.4976 Acc: 0.1917
# val Loss: 3.7457 Acc: 0.1003
# Epoch 46/49
# ----------
# train Loss: 4.4806 Acc: 0.1829
# val Loss: 3.7085 Acc: 0.1109
# Epoch 47/49
# ----------
# train Loss: 4.4375 Acc: 0.1988
# val Loss: 3.7165 Acc: 0.1096
# Epoch 48/49
# ----------
# train Loss: 4.4494 Acc: 0.1938
# val Loss: 3.7309 Acc: 0.1053
# Epoch 49/49
# ----------
# train Loss: 4.4567 Acc: 0.1877
# val Loss: 3.7211 Acc: 0.1065
# Training complete in 82m 36s
# Best val Acc: 0.113409
# (Inception3(
#    (Conv2d_1a_3x3): BasicConv2d(
#      (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#      (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    )
#    (Conv2d_2a_3x3): BasicConv2d(
#      (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#      (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    )
#    (Conv2d_2b_3x3): BasicConv2d(
#      (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    )
#    (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#    (Conv2d_3b_1x1): BasicConv2d(
#      (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#      (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    )
#    (Conv2d_4a_3x3): BasicConv2d(
#      (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#      (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    )
#    (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#    (Mixed_5b): InceptionA(
#      (branch1x1): BasicConv2d(
#        (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch5x5_1): BasicConv2d(
#        (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch5x5_2): BasicConv2d(
#        (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_1): BasicConv2d(
#        (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_2): BasicConv2d(
#        (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_3): BasicConv2d(
#        (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch_pool): BasicConv2d(
#        (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (Mixed_5c): InceptionA(
#      (branch1x1): BasicConv2d(
#        (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch5x5_1): BasicConv2d(
#        (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch5x5_2): BasicConv2d(
#        (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_1): BasicConv2d(
#        (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_2): BasicConv2d(
#        (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_3): BasicConv2d(
#        (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch_pool): BasicConv2d(
#        (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (Mixed_5d): InceptionA(
#      (branch1x1): BasicConv2d(
#        (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch5x5_1): BasicConv2d(
#        (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch5x5_2): BasicConv2d(
#        (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_1): BasicConv2d(
#        (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_2): BasicConv2d(
#        (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_3): BasicConv2d(
#        (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch_pool): BasicConv2d(
#        (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (Mixed_6a): InceptionB(
#      (branch3x3): BasicConv2d(
#        (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_1): BasicConv2d(
#        (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_2): BasicConv2d(
#        (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_3): BasicConv2d(
#        (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#        (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (Mixed_6b): InceptionC(
#      (branch1x1): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_1): BasicConv2d(
#        (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_2): BasicConv2d(
#        (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_3): BasicConv2d(
#        (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_1): BasicConv2d(
#        (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_2): BasicConv2d(
#        (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_3): BasicConv2d(
#        (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_4): BasicConv2d(
#        (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_5): BasicConv2d(
#        (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch_pool): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (Mixed_6c): InceptionC(
#      (branch1x1): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_1): BasicConv2d(
#        (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_2): BasicConv2d(
#        (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_3): BasicConv2d(
#        (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_1): BasicConv2d(
#        (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_2): BasicConv2d(
#        (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_3): BasicConv2d(
#        (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_4): BasicConv2d(
#        (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_5): BasicConv2d(
#        (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch_pool): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (Mixed_6d): InceptionC(
#      (branch1x1): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_1): BasicConv2d(
#        (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_2): BasicConv2d(
#        (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_3): BasicConv2d(
#        (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_1): BasicConv2d(
#        (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_2): BasicConv2d(
#        (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_3): BasicConv2d(
#        (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_4): BasicConv2d(
#        (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_5): BasicConv2d(
#        (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch_pool): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (Mixed_6e): InceptionC(
#      (branch1x1): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_1): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_2): BasicConv2d(
#        (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_3): BasicConv2d(
#        (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_1): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_2): BasicConv2d(
#        (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_3): BasicConv2d(
#        (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_4): BasicConv2d(
#        (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_5): BasicConv2d(
#        (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch_pool): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (AuxLogits): InceptionAux(
#      (conv0): BasicConv2d(
#        (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (conv1): BasicConv2d(
#        (conv): Conv2d(128, 768, kernel_size=(5, 5), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (fc): Linear(in_features=768, out_features=80, bias=True)
#    )
#    (Mixed_7a): InceptionD(
#      (branch3x3_1): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3_2): BasicConv2d(
#        (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#        (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7x3_1): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7x3_2): BasicConv2d(
#        (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7x3_3): BasicConv2d(
#        (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7x3_4): BasicConv2d(
#        (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (Mixed_7b): InceptionE(
#      (branch1x1): BasicConv2d(
#        (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3_1): BasicConv2d(
#        (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3_2a): BasicConv2d(
#        (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3_2b): BasicConv2d(
#        (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_1): BasicConv2d(
#        (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_2): BasicConv2d(
#        (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_3a): BasicConv2d(
#        (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_3b): BasicConv2d(
#        (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch_pool): BasicConv2d(
#        (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (Mixed_7c): InceptionE(
#      (branch1x1): BasicConv2d(
#        (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3_1): BasicConv2d(
#        (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3_2a): BasicConv2d(
#        (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3_2b): BasicConv2d(
#        (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_1): BasicConv2d(
#        (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_2): BasicConv2d(
#        (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_3a): BasicConv2d(
#        (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_3b): BasicConv2d(
#        (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch_pool): BasicConv2d(
#        (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#    (dropout): Dropout(p=0.5, inplace=False)
#    (fc): Linear(in_features=2048, out_features=80, bias=True)
#  ),
#  [0.041353383458646614,
#   0.045112781954887216,
#   0.05513784461152882,
#   0.06829573934837092,
#   0.06954887218045112,
#   0.07644110275689223,
#   0.08020050125313283,
#   0.08897243107769423,
#   0.08208020050125313,
#   0.09147869674185463,
#   0.08458646616541353,
#   0.07957393483709273,
#   0.08771929824561403,
#   0.09774436090225563,
#   0.09335839598997493,
#   0.09461152882205513,
#   0.09649122807017543,
#   0.09837092731829573,
#   0.09335839598997493,
#   0.09398496240601503,
#   0.11027568922305764,
#   0.10338345864661654,
#   0.10526315789473684,
#   0.10150375939849623,
#   0.09899749373433583,
#   0.09711779448621553,
#   0.09899749373433583,
#   0.10401002506265664,
#   0.09523809523809523,
#   0.10338345864661654,
#   0.10338345864661654,
#   0.11340852130325814,
#   0.10275689223057644,
#   0.11152882205513784,
#   0.11027568922305764,
#   0.10651629072681704,
#   0.09962406015037593,
#   0.11152882205513784,
#   0.10902255639097744,
#   0.10714285714285714,
#   0.10714285714285714,
#   0.10463659147869674,
#   0.10839598997493734,
#   0.09962406015037593,
#   0.10275689223057644,
#   0.10025062656641603,
#   0.11090225563909774,
#   0.10964912280701754,
#   0.10526315789473684,
#   0.10651629072681704])

# %% [markdown]
# ## Testing Model

# %%
def test_model(model, datasets, batch_size=64, learning_rate=1e-3, aux_coef=0.4, num_epochs=5):
    since = time.time()

    dataloaders = {x: torch.utils.data.DataLoader(datasets[x], 
                                                  batch_size=batch_size, 
                                                  shuffle=True, 
                                                  num_workers=1) for x in ['test']}

    # Observe that some parameters are being optimized
    optimizer = optim.Adam(params_to_update, lr=learning_rate)
    # Setup the loss fxn
    criterion = nn.CrossEntropyLoss()

    test_loss_history = []
    test_acc_history = []
    epochs = np.arange(0,num_epochs)

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['test']:
            if phase == 'test':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:

                #############################################
                #To Enable GPU Usage
                if use_cuda and torch.cuda.is_available():
                  inputs = inputs.cuda()
                  labels = labels.cuda()
                #############################################

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'test'):
                    # Get model outputs and calculate loss
                    # Special case for the loss by summing the final output and the auxiliary output
                    #   but in testing inception because in training it has an auxiliary output. In train
                    #   mode we calculate  only consider the final output.
                    if phase == 'test':
                        # From https://discuss.pytorch.org/t/how-to-optimize-inception-model-with-auxiliary-classifiers/7958
                        outputs, aux_outputs = model(inputs)
                        loss1 = criterion(outputs, labels)
                        loss2 = criterion(aux_outputs, labels)
                        loss = loss1 + aux_coef*loss2

                    # _, preds = torch.max(outputs, 1)
                    preds = outputs.max(1, keepdim=True)[1]

                    # backward + optimize only if in training phase
                    if phase == 'test':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += preds.eq(labels.view_as(preds)).sum().item()
                print('{} Running Loss: {:.4f} Running Acc: {:.4f}'.format(phase, running_loss, running_corrects))
                # running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = float(running_corrects) / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            if phase == 'test':
              test_acc_history.append(epoch_acc)
              test_loss_history.append(epoch_loss)

        # print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))

    plt.title("Training Loss Curve")
    plt.plot(epochs, test_loss_history, label="Train")
    plt.xlabel("Iterations")
    plt.ylabel("Loss")
    plt.show()

    plt.title("Training Accuracy Curve")
    plt.plot(epochs, test_acc_history, label="Train")
    plt.xlabel("Iterations")
    plt.ylabel("Training Accuracy")
    plt.show()

    return

# %%
model, params_to_update = init_model()

if use_cuda and torch.cuda.is_available():
  model = model.cuda()
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')

test_model(model, datasets=image_datasets, batch_size=256, learning_rate=1e-3, aux_coef=0.4, num_epochs=100)
# Out:
# CUDA is available!  Training on GPU ...
# Epoch 0/99
# ----------
# test Running Loss: 1589.3665 Running Acc: 3.0000
# test Running Loss: 3183.9863 Running Acc: 6.0000
# test Running Loss: 4796.6870 Running Acc: 9.0000
# test Running Loss: 4994.9287 Running Acc: 9.0000
# test Loss: 6.2515 Acc: 0.0113
# Epoch 1/99
# ----------
# test Running Loss: 1508.5918 Running Acc: 11.0000
# test Running Loss: 3013.4714 Running Acc: 16.0000
# test Running Loss: 4533.3798 Running Acc: 19.0000
# test Running Loss: 4717.4067 Running Acc: 19.0000
# test Loss: 5.9041 Acc: 0.0238
# Epoch 2/99
# ----------
# test Running Loss: 1454.4290 Running Acc: 23.0000
# test Running Loss: 2923.3306 Running Acc: 42.0000
# test Running Loss: 4392.9286 Running Acc: 51.0000
# test Running Loss: 4569.2199 Running Acc: 51.0000
# test Loss: 5.7187 Acc: 0.0638
# Epoch 3/99
# ----------
# test Running Loss: 1416.6405 Running Acc: 25.0000
# test Running Loss: 2812.5770 Running Acc: 47.0000
# test Running Loss: 4201.9113 Running Acc: 74.0000
# test Running Loss: 4371.9422 Running Acc: 76.0000
# test Loss: 5.4718 Acc: 0.0951
# Epoch 4/99
# ----------
# test Running Loss: 1347.4292 Running Acc: 36.0000
# test Running Loss: 2691.7136 Running Acc: 88.0000
# test Running Loss: 4029.7869 Running Acc: 144.0000
# test Running Loss: 4198.4954 Running Acc: 148.0000
# test Loss: 5.2547 Acc: 0.1852
# Epoch 5/99
# ----------
# test Running Loss: 1315.0376 Running Acc: 47.0000
# test Running Loss: 2604.8855 Running Acc: 103.0000
# test Running Loss: 3889.6140 Running Acc: 156.0000
# test Running Loss: 4045.4558 Running Acc: 159.0000
# test Loss: 5.0631 Acc: 0.1990
# Epoch 6/99
# ----------
# test Running Loss: 1265.4106 Running Acc: 54.0000
# test Running Loss: 2510.2452 Running Acc: 118.0000
# test Running Loss: 3757.8496 Running Acc: 180.0000
# test Running Loss: 3908.6836 Running Acc: 184.0000
# test Loss: 4.8920 Acc: 0.2303
# Epoch 7/99
# ----------
# test Running Loss: 1208.7345 Running Acc: 59.0000
# test Running Loss: 2418.7393 Running Acc: 124.0000
# test Running Loss: 3613.7125 Running Acc: 192.0000
# test Running Loss: 3759.0313 Running Acc: 200.0000
# test Loss: 4.7047 Acc: 0.2503
# Epoch 8/99
# ----------
# test Running Loss: 1162.2153 Running Acc: 85.0000
# test Running Loss: 2328.0276 Running Acc: 165.0000
# test Running Loss: 3480.9736 Running Acc: 256.0000
# test Running Loss: 3625.3081 Running Acc: 266.0000
# test Loss: 4.5373 Acc: 0.3329
# Epoch 9/99
# ----------
# test Running Loss: 1142.1561 Running Acc: 101.0000
# test Running Loss: 2241.6133 Running Acc: 219.0000
# test Running Loss: 3364.6941 Running Acc: 313.0000
# test Running Loss: 3492.9501 Running Acc: 331.0000
# test Loss: 4.3717 Acc: 0.4143
# Epoch 10/99
# ----------
# test Running Loss: 1090.1558 Running Acc: 106.0000
# test Running Loss: 2192.5211 Running Acc: 205.0000
# test Running Loss: 3264.7346 Running Acc: 308.0000
# test Running Loss: 3395.5162 Running Acc: 320.0000
# test Loss: 4.2497 Acc: 0.4005
# Epoch 11/99
# ----------
# test Running Loss: 1050.4631 Running Acc: 113.0000
# test Running Loss: 2090.2491 Running Acc: 246.0000
# test Running Loss: 3147.2612 Running Acc: 358.0000
# test Running Loss: 3279.5562 Running Acc: 368.0000
# test Loss: 4.1046 Acc: 0.4606
# Epoch 12/99
# ----------
# test Running Loss: 1003.7175 Running Acc: 143.0000
# test Running Loss: 2023.9066 Running Acc: 274.0000
# test Running Loss: 3022.2726 Running Acc: 408.0000
# test Running Loss: 3147.9630 Running Acc: 421.0000
# test Loss: 3.9399 Acc: 0.5269
# Epoch 13/99
# ----------
# test Running Loss: 979.9940 Running Acc: 146.0000
# test Running Loss: 1949.9622 Running Acc: 291.0000
# test Running Loss: 2914.6939 Running Acc: 440.0000
# test Running Loss: 3037.1684 Running Acc: 454.0000
# test Loss: 3.8012 Acc: 0.5682
# Epoch 14/99
# ----------
# test Running Loss: 944.1350 Running Acc: 149.0000
# test Running Loss: 1899.1213 Running Acc: 303.0000
# test Running Loss: 2832.7547 Running Acc: 462.0000
# test Running Loss: 2949.0138 Running Acc: 482.0000
# test Loss: 3.6909 Acc: 0.6033
# Epoch 15/99
# ----------
# test Running Loss: 899.7696 Running Acc: 173.0000
# test Running Loss: 1799.9732 Running Acc: 325.0000
# test Running Loss: 2735.4833 Running Acc: 467.0000
# test Running Loss: 2859.0026 Running Acc: 478.0000
# test Loss: 3.5782 Acc: 0.5982
# Epoch 16/99
# ----------
# test Running Loss: 894.8988 Running Acc: 154.0000
# test Running Loss: 1770.7111 Running Acc: 314.0000
# test Running Loss: 2659.1570 Running Acc: 472.0000
# test Running Loss: 2770.4631 Running Acc: 491.0000
# test Loss: 3.4674 Acc: 0.6145
# Epoch 17/99
# ----------
# test Running Loss: 863.6395 Running Acc: 164.0000
# test Running Loss: 1708.9407 Running Acc: 341.0000
# test Running Loss: 2550.7295 Running Acc: 522.0000
# test Running Loss: 2661.1766 Running Acc: 541.0000
# test Loss: 3.3306 Acc: 0.6771
# Epoch 18/99
# ----------
# test Running Loss: 825.3162 Running Acc: 185.0000
# test Running Loss: 1630.8708 Running Acc: 385.0000
# test Running Loss: 2471.3335 Running Acc: 555.0000
# test Running Loss: 2581.6022 Running Acc: 574.0000
# test Loss: 3.2310 Acc: 0.7184
# Epoch 19/99
# ----------
# test Running Loss: 799.5166 Running Acc: 191.0000
# test Running Loss: 1564.5840 Running Acc: 392.0000
# test Running Loss: 2357.8246 Running Acc: 586.0000
# test Running Loss: 2466.2958 Running Acc: 602.0000
# test Loss: 3.0867 Acc: 0.7534
# Epoch 20/99
# ----------
# test Running Loss: 762.4700 Running Acc: 205.0000
# test Running Loss: 1564.4163 Running Acc: 384.0000
# test Running Loss: 2322.9288 Running Acc: 577.0000
# test Running Loss: 2425.9495 Running Acc: 600.0000
# test Loss: 3.0362 Acc: 0.7509
# Epoch 21/99
# ----------
# test Running Loss: 774.8407 Running Acc: 186.0000
# test Running Loss: 1518.4045 Running Acc: 387.0000
# test Running Loss: 2260.6574 Running Acc: 588.0000
# test Running Loss: 2357.4710 Running Acc: 610.0000
# test Loss: 2.9505 Acc: 0.7635
# Epoch 22/99
# ----------
# test Running Loss: 735.1646 Running Acc: 203.0000
# test Running Loss: 1447.1929 Running Acc: 414.0000
# test Running Loss: 2149.9263 Running Acc: 624.0000
# test Running Loss: 2244.2337 Running Acc: 649.0000
# test Loss: 2.8088 Acc: 0.8123
# Epoch 23/99
# ----------
# test Running Loss: 729.1378 Running Acc: 190.0000
# test Running Loss: 1408.3550 Running Acc: 407.0000
# test Running Loss: 2107.0909 Running Acc: 610.0000
# test Running Loss: 2196.5708 Running Acc: 634.0000
# test Loss: 2.7491 Acc: 0.7935
# Epoch 24/99
# ----------
# test Running Loss: 700.9675 Running Acc: 200.0000
# test Running Loss: 1382.6384 Running Acc: 409.0000
# test Running Loss: 2048.3182 Running Acc: 622.0000
# test Running Loss: 2133.3111 Running Acc: 645.0000
# test Loss: 2.6700 Acc: 0.8073
# Epoch 25/99
# ----------
# test Running Loss: 676.8035 Running Acc: 204.0000
# test Running Loss: 1319.3227 Running Acc: 417.0000
# test Running Loss: 1973.7544 Running Acc: 618.0000
# test Running Loss: 2063.2843 Running Acc: 640.0000
# test Loss: 2.5823 Acc: 0.8010
# Epoch 26/99
# ----------
# test Running Loss: 650.4091 Running Acc: 206.0000
# test Running Loss: 1274.3954 Running Acc: 420.0000
# test Running Loss: 1910.6140 Running Acc: 636.0000
# test Running Loss: 1992.5289 Running Acc: 659.0000
# test Loss: 2.4938 Acc: 0.8248
# Epoch 27/99
# ----------
# test Running Loss: 593.5959 Running Acc: 228.0000
# test Running Loss: 1227.8473 Running Acc: 441.0000
# test Running Loss: 1848.8524 Running Acc: 644.0000
# test Running Loss: 1922.6031 Running Acc: 669.0000
# test Loss: 2.4063 Acc: 0.8373
# Epoch 28/99
# ----------
# test Running Loss: 592.0410 Running Acc: 213.0000
# test Running Loss: 1196.1487 Running Acc: 427.0000
# test Running Loss: 1799.1057 Running Acc: 626.0000
# test Running Loss: 1885.9236 Running Acc: 646.0000
# test Loss: 2.3604 Acc: 0.8085
# Epoch 29/99
# ----------
# test Running Loss: 579.6033 Running Acc: 209.0000
# test Running Loss: 1151.2850 Running Acc: 430.0000
# test Running Loss: 1739.3638 Running Acc: 638.0000
# test Running Loss: 1823.9579 Running Acc: 659.0000
# test Loss: 2.2828 Acc: 0.8248
# Epoch 30/99
# ----------
# test Running Loss: 568.1270 Running Acc: 216.0000
# test Running Loss: 1097.9510 Running Acc: 438.0000
# test Running Loss: 1663.5720 Running Acc: 655.0000
# test Running Loss: 1743.5276 Running Acc: 676.0000
# test Loss: 2.1821 Acc: 0.8461
# Epoch 31/99
# ----------
# test Running Loss: 537.8260 Running Acc: 224.0000
# test Running Loss: 1090.3669 Running Acc: 439.0000
# test Running Loss: 1641.4469 Running Acc: 653.0000
# test Running Loss: 1712.0320 Running Acc: 677.0000
# test Loss: 2.1427 Acc: 0.8473
# Epoch 32/99
# ----------
# test Running Loss: 536.2583 Running Acc: 208.0000
# test Running Loss: 1072.8212 Running Acc: 426.0000
# test Running Loss: 1599.6751 Running Acc: 644.0000
# test Running Loss: 1676.4571 Running Acc: 665.0000
# test Loss: 2.0982 Acc: 0.8323
# Epoch 33/99
# ----------
# test Running Loss: 490.2767 Running Acc: 219.0000
# test Running Loss: 1014.3324 Running Acc: 437.0000
# test Running Loss: 1541.7904 Running Acc: 649.0000
# test Running Loss: 1614.2995 Running Acc: 672.0000
# test Loss: 2.0204 Acc: 0.8411
# Epoch 34/99
# ----------
# test Running Loss: 500.9345 Running Acc: 220.0000
# test Running Loss: 1006.2536 Running Acc: 442.0000
# test Running Loss: 1497.6896 Running Acc: 663.0000
# test Running Loss: 1571.9568 Running Acc: 684.0000
# test Loss: 1.9674 Acc: 0.8561
# Epoch 35/99
# ----------
# test Running Loss: 478.8790 Running Acc: 227.0000
# test Running Loss: 986.2740 Running Acc: 447.0000
# test Running Loss: 1469.1020 Running Acc: 675.0000
# test Running Loss: 1539.5655 Running Acc: 698.0000
# test Loss: 1.9269 Acc: 0.8736
# Epoch 36/99
# ----------
# test Running Loss: 459.2130 Running Acc: 228.0000
# test Running Loss: 945.7673 Running Acc: 442.0000
# test Running Loss: 1394.1377 Running Acc: 675.0000
# test Running Loss: 1469.4262 Running Acc: 699.0000
# test Loss: 1.8391 Acc: 0.8748
# Epoch 37/99
# ----------
# test Running Loss: 453.0984 Running Acc: 233.0000
# test Running Loss: 904.1567 Running Acc: 458.0000
# test Running Loss: 1364.0341 Running Acc: 684.0000
# test Running Loss: 1428.3570 Running Acc: 709.0000
# test Loss: 1.7877 Acc: 0.8874
# Epoch 38/99
# ----------
# test Running Loss: 437.9046 Running Acc: 229.0000
# test Running Loss: 909.3020 Running Acc: 457.0000
# test Running Loss: 1355.5944 Running Acc: 688.0000
# test Running Loss: 1427.0826 Running Acc: 711.0000
# test Loss: 1.7861 Acc: 0.8899
# Epoch 39/99
# ----------
# test Running Loss: 429.2347 Running Acc: 225.0000
# test Running Loss: 868.6584 Running Acc: 448.0000
# test Running Loss: 1293.2105 Running Acc: 683.0000
# test Running Loss: 1353.4388 Running Acc: 707.0000
# test Loss: 1.6939 Acc: 0.8849
# Epoch 40/99
# ----------
# test Running Loss: 416.2186 Running Acc: 236.0000
# test Running Loss: 817.7414 Running Acc: 474.0000
# test Running Loss: 1248.5570 Running Acc: 709.0000
# test Running Loss: 1311.2476 Running Acc: 736.0000
# test Loss: 1.6411 Acc: 0.9212
# Epoch 41/99
# ----------
# test Running Loss: 397.1218 Running Acc: 229.0000
# test Running Loss: 803.4151 Running Acc: 470.0000
# test Running Loss: 1199.4616 Running Acc: 705.0000
# test Running Loss: 1258.7410 Running Acc: 730.0000
# test Loss: 1.5754 Acc: 0.9136
# Epoch 42/99
# ----------
# test Running Loss: 384.6232 Running Acc: 244.0000
# test Running Loss: 784.8770 Running Acc: 475.0000
# test Running Loss: 1192.7988 Running Acc: 707.0000
# test Running Loss: 1250.7171 Running Acc: 732.0000
# test Loss: 1.5654 Acc: 0.9161
# Epoch 43/99
# ----------
# test Running Loss: 391.7044 Running Acc: 234.0000
# test Running Loss: 777.4820 Running Acc: 475.0000
# test Running Loss: 1155.8685 Running Acc: 705.0000
# test Running Loss: 1209.8691 Running Acc: 731.0000
# test Loss: 1.5142 Acc: 0.9149
# Epoch 44/99
# ----------
# test Running Loss: 371.1637 Running Acc: 237.0000
# test Running Loss: 765.3680 Running Acc: 475.0000
# test Running Loss: 1142.5772 Running Acc: 709.0000
# test Running Loss: 1200.1602 Running Acc: 734.0000
# test Loss: 1.5021 Acc: 0.9186
# Epoch 45/99
# ----------
# test Running Loss: 365.6577 Running Acc: 234.0000
# test Running Loss: 708.3182 Running Acc: 475.0000
# test Running Loss: 1089.0939 Running Acc: 715.0000
# test Running Loss: 1139.7109 Running Acc: 744.0000
# test Loss: 1.4264 Acc: 0.9312
# Epoch 46/99
# ----------
# test Running Loss: 358.3360 Running Acc: 238.0000
# test Running Loss: 720.1041 Running Acc: 471.0000
# test Running Loss: 1071.1357 Running Acc: 711.0000
# test Running Loss: 1120.8768 Running Acc: 739.0000
# test Loss: 1.4028 Acc: 0.9249
# Epoch 47/99
# ----------
# test Running Loss: 354.5457 Running Acc: 236.0000
# test Running Loss: 709.4951 Running Acc: 473.0000
# test Running Loss: 1049.3897 Running Acc: 713.0000
# test Running Loss: 1109.3058 Running Acc: 737.0000
# test Loss: 1.3884 Acc: 0.9224
# Epoch 48/99
# ----------
# test Running Loss: 336.8262 Running Acc: 239.0000
# test Running Loss: 680.7530 Running Acc: 477.0000
# test Running Loss: 1031.5850 Running Acc: 718.0000
# test Running Loss: 1082.4025 Running Acc: 745.0000
# test Loss: 1.3547 Acc: 0.9324
# Epoch 49/99
# ----------
# test Running Loss: 329.5789 Running Acc: 235.0000
# test Running Loss: 654.1598 Running Acc: 483.0000
# test Running Loss: 997.5927 Running Acc: 715.0000
# test Running Loss: 1047.1726 Running Acc: 740.0000
# test Loss: 1.3106 Acc: 0.9262
# Epoch 50/99
# ----------
# test Running Loss: 322.3557 Running Acc: 244.0000
# test Running Loss: 639.1558 Running Acc: 487.0000
# test Running Loss: 949.5196 Running Acc: 728.0000
# test Running Loss: 1003.6960 Running Acc: 758.0000
# test Loss: 1.2562 Acc: 0.9487
# Epoch 51/99
# ----------
# test Running Loss: 325.1128 Running Acc: 243.0000
# test Running Loss: 648.7090 Running Acc: 483.0000
# test Running Loss: 957.9826 Running Acc: 727.0000
# test Running Loss: 999.9840 Running Acc: 756.0000
# test Loss: 1.2515 Acc: 0.9462
# Epoch 52/99
# ----------
# test Running Loss: 316.0059 Running Acc: 239.0000
# test Running Loss: 628.4460 Running Acc: 480.0000
# test Running Loss: 924.5624 Running Acc: 724.0000
# test Running Loss: 969.4755 Running Acc: 752.0000
# test Loss: 1.2134 Acc: 0.9412
# Epoch 53/99
# ----------
# test Running Loss: 290.2474 Running Acc: 243.0000
# test Running Loss: 606.0019 Running Acc: 482.0000
# test Running Loss: 917.7404 Running Acc: 723.0000
# test Running Loss: 964.4363 Running Acc: 751.0000
# test Loss: 1.2071 Acc: 0.9399
# Epoch 54/99
# ----------
# test Running Loss: 298.5627 Running Acc: 245.0000
# test Running Loss: 583.3910 Running Acc: 486.0000
# test Running Loss: 874.0726 Running Acc: 728.0000
# test Running Loss: 922.8044 Running Acc: 755.0000
# test Loss: 1.1549 Acc: 0.9449
# Epoch 55/99
# ----------
# test Running Loss: 280.2056 Running Acc: 247.0000
# test Running Loss: 572.8907 Running Acc: 486.0000
# test Running Loss: 863.1974 Running Acc: 729.0000
# test Running Loss: 909.4415 Running Acc: 758.0000
# test Loss: 1.1382 Acc: 0.9487
# Epoch 56/99
# ----------
# test Running Loss: 269.5280 Running Acc: 241.0000
# test Running Loss: 557.1678 Running Acc: 489.0000
# test Running Loss: 829.7416 Running Acc: 733.0000
# test Running Loss: 872.5690 Running Acc: 760.0000
# test Loss: 1.0921 Acc: 0.9512
# Epoch 57/99
# ----------
# test Running Loss: 273.1610 Running Acc: 244.0000
# test Running Loss: 539.7206 Running Acc: 492.0000
# test Running Loss: 810.4424 Running Acc: 737.0000
# test Running Loss: 854.6890 Running Acc: 764.0000
# test Loss: 1.0697 Acc: 0.9562
# Epoch 58/99
# ----------
# test Running Loss: 265.8442 Running Acc: 245.0000
# test Running Loss: 533.2029 Running Acc: 490.0000
# test Running Loss: 805.7997 Running Acc: 728.0000
# test Running Loss: 848.4864 Running Acc: 756.0000
# test Loss: 1.0619 Acc: 0.9462
# Epoch 59/99
# ----------
# test Running Loss: 263.1143 Running Acc: 246.0000
# test Running Loss: 511.2464 Running Acc: 494.0000
# test Running Loss: 776.4223 Running Acc: 743.0000
# test Running Loss: 815.8965 Running Acc: 771.0000
# test Loss: 1.0211 Acc: 0.9650
# Epoch 60/99
# ----------
# test Running Loss: 236.6274 Running Acc: 249.0000
# test Running Loss: 499.0902 Running Acc: 497.0000
# test Running Loss: 763.9146 Running Acc: 741.0000
# test Running Loss: 809.2107 Running Acc: 768.0000
# test Loss: 1.0128 Acc: 0.9612
# Epoch 61/99
# ----------
# test Running Loss: 239.2686 Running Acc: 248.0000
# test Running Loss: 495.6936 Running Acc: 496.0000
# test Running Loss: 748.3036 Running Acc: 742.0000
# test Running Loss: 785.5214 Running Acc: 771.0000
# test Loss: 0.9831 Acc: 0.9650
# Epoch 62/99
# ----------
# test Running Loss: 243.2640 Running Acc: 244.0000
# test Running Loss: 493.1036 Running Acc: 483.0000
# test Running Loss: 743.6028 Running Acc: 733.0000
# test Running Loss: 781.6051 Running Acc: 762.0000
# test Loss: 0.9782 Acc: 0.9537
# Epoch 63/99
# ----------
# test Running Loss: 236.2048 Running Acc: 248.0000
# test Running Loss: 472.0455 Running Acc: 495.0000
# test Running Loss: 690.1294 Running Acc: 748.0000
# test Running Loss: 737.1278 Running Acc: 774.0000
# test Loss: 0.9226 Acc: 0.9687
# Epoch 64/99
# ----------
# test Running Loss: 234.1727 Running Acc: 245.0000
# test Running Loss: 462.2198 Running Acc: 492.0000
# test Running Loss: 694.7720 Running Acc: 742.0000
# test Running Loss: 731.4697 Running Acc: 771.0000
# test Loss: 0.9155 Acc: 0.9650
# Epoch 65/99
# ----------
# test Running Loss: 222.7182 Running Acc: 248.0000
# test Running Loss: 447.3058 Running Acc: 493.0000
# test Running Loss: 681.0387 Running Acc: 743.0000
# test Running Loss: 719.1272 Running Acc: 772.0000
# test Loss: 0.9000 Acc: 0.9662
# Epoch 66/99
# ----------
# test Running Loss: 214.6634 Running Acc: 250.0000
# test Running Loss: 451.8936 Running Acc: 501.0000
# test Running Loss: 677.1537 Running Acc: 752.0000
# test Running Loss: 715.9097 Running Acc: 780.0000
# test Loss: 0.8960 Acc: 0.9762
# Epoch 67/99
# ----------
# test Running Loss: 223.0395 Running Acc: 247.0000
# test Running Loss: 443.3217 Running Acc: 493.0000
# test Running Loss: 660.6320 Running Acc: 745.0000
# test Running Loss: 694.0269 Running Acc: 774.0000
# test Loss: 0.8686 Acc: 0.9687
# Epoch 68/99
# ----------
# test Running Loss: 209.7173 Running Acc: 247.0000
# test Running Loss: 418.7793 Running Acc: 497.0000
# test Running Loss: 639.7858 Running Acc: 747.0000
# test Running Loss: 676.4304 Running Acc: 776.0000
# test Loss: 0.8466 Acc: 0.9712
# Epoch 69/99
# ----------
# test Running Loss: 215.0410 Running Acc: 246.0000
# test Running Loss: 430.6998 Running Acc: 493.0000
# test Running Loss: 639.9941 Running Acc: 745.0000
# test Running Loss: 683.9305 Running Acc: 772.0000
# test Loss: 0.8560 Acc: 0.9662
# Epoch 70/99
# ----------
# test Running Loss: 221.0274 Running Acc: 246.0000
# test Running Loss: 412.0404 Running Acc: 498.0000
# test Running Loss: 608.5010 Running Acc: 743.0000
# test Running Loss: 643.1631 Running Acc: 772.0000
# test Loss: 0.8050 Acc: 0.9662
# Epoch 71/99
# ----------
# test Running Loss: 195.7508 Running Acc: 243.0000
# test Running Loss: 405.4092 Running Acc: 492.0000
# test Running Loss: 623.2756 Running Acc: 739.0000
# test Running Loss: 663.5388 Running Acc: 765.0000
# test Loss: 0.8305 Acc: 0.9574
# Epoch 72/99
# ----------
# test Running Loss: 212.0020 Running Acc: 246.0000
# test Running Loss: 402.8412 Running Acc: 496.0000
# test Running Loss: 606.3596 Running Acc: 748.0000
# test Running Loss: 642.4992 Running Acc: 776.0000
# test Loss: 0.8041 Acc: 0.9712
# Epoch 73/99
# ----------
# test Running Loss: 194.6841 Running Acc: 251.0000
# test Running Loss: 386.8018 Running Acc: 502.0000
# test Running Loss: 583.6747 Running Acc: 754.0000
# test Running Loss: 621.9394 Running Acc: 783.0000
# test Loss: 0.7784 Acc: 0.9800
# Epoch 74/99
# ----------
# test Running Loss: 195.6775 Running Acc: 249.0000
# test Running Loss: 382.1788 Running Acc: 501.0000
# test Running Loss: 567.7262 Running Acc: 752.0000
# test Running Loss: 603.5076 Running Acc: 781.0000
# test Loss: 0.7553 Acc: 0.9775
# Epoch 75/99
# ----------
# test Running Loss: 182.8670 Running Acc: 252.0000
# test Running Loss: 355.8126 Running Acc: 502.0000
# test Running Loss: 537.1749 Running Acc: 756.0000
# test Running Loss: 568.5356 Running Acc: 785.0000
# test Loss: 0.7116 Acc: 0.9825
# Epoch 76/99
# ----------
# test Running Loss: 185.2905 Running Acc: 251.0000
# test Running Loss: 375.4754 Running Acc: 501.0000
# test Running Loss: 570.5279 Running Acc: 749.0000
# test Running Loss: 600.6046 Running Acc: 776.0000
# test Loss: 0.7517 Acc: 0.9712
# Epoch 77/99
# ----------
# test Running Loss: 175.1339 Running Acc: 250.0000
# test Running Loss: 344.6644 Running Acc: 502.0000
# test Running Loss: 518.5961 Running Acc: 753.0000
# test Running Loss: 552.7659 Running Acc: 783.0000
# test Loss: 0.6918 Acc: 0.9800
# Epoch 78/99
# ----------
# test Running Loss: 184.0801 Running Acc: 252.0000
# test Running Loss: 348.8629 Running Acc: 507.0000
# test Running Loss: 516.6228 Running Acc: 758.0000
# test Running Loss: 550.5358 Running Acc: 787.0000
# test Loss: 0.6890 Acc: 0.9850
# Epoch 79/99
# ----------
# test Running Loss: 181.1394 Running Acc: 250.0000
# test Running Loss: 348.4982 Running Acc: 502.0000
# test Running Loss: 514.4457 Running Acc: 754.0000
# test Running Loss: 542.8074 Running Acc: 784.0000
# test Loss: 0.6794 Acc: 0.9812
# Epoch 80/99
# ----------
# test Running Loss: 154.9596 Running Acc: 254.0000
# test Running Loss: 329.3003 Running Acc: 504.0000
# test Running Loss: 492.7416 Running Acc: 756.0000
# test Running Loss: 521.2533 Running Acc: 784.0000
# test Loss: 0.6524 Acc: 0.9812
# Epoch 81/99
# ----------
# test Running Loss: 178.0124 Running Acc: 251.0000
# test Running Loss: 338.3410 Running Acc: 502.0000
# test Running Loss: 503.7480 Running Acc: 755.0000
# test Running Loss: 535.7469 Running Acc: 784.0000
# test Loss: 0.6705 Acc: 0.9812
# Epoch 82/99
# ----------
# test Running Loss: 167.0343 Running Acc: 253.0000
# test Running Loss: 323.7384 Running Acc: 507.0000
# test Running Loss: 491.2687 Running Acc: 760.0000
# test Running Loss: 520.9743 Running Acc: 789.0000
# test Loss: 0.6520 Acc: 0.9875
# Epoch 83/99
# ----------
# test Running Loss: 152.7891 Running Acc: 254.0000
# test Running Loss: 323.0774 Running Acc: 502.0000
# test Running Loss: 466.8623 Running Acc: 756.0000
# test Running Loss: 511.3261 Running Acc: 784.0000
# test Loss: 0.6400 Acc: 0.9812
# Epoch 84/99
# ----------
# test Running Loss: 162.8914 Running Acc: 250.0000
# test Running Loss: 320.0012 Running Acc: 503.0000
# test Running Loss: 473.3803 Running Acc: 756.0000
# test Running Loss: 500.0014 Running Acc: 786.0000
# test Loss: 0.6258 Acc: 0.9837
# Epoch 85/99
# ----------
# test Running Loss: 159.6187 Running Acc: 252.0000
# test Running Loss: 308.7143 Running Acc: 503.0000
# test Running Loss: 455.0667 Running Acc: 757.0000
# test Running Loss: 476.6742 Running Acc: 788.0000
# test Loss: 0.5966 Acc: 0.9862
# Epoch 86/99
# ----------
# test Running Loss: 141.3452 Running Acc: 255.0000
# test Running Loss: 296.0622 Running Acc: 508.0000
# test Running Loss: 447.3972 Running Acc: 761.0000
# test Running Loss: 472.7418 Running Acc: 791.0000
# test Loss: 0.5917 Acc: 0.9900
# Epoch 87/99
# ----------
# test Running Loss: 162.9826 Running Acc: 252.0000
# test Running Loss: 309.6038 Running Acc: 506.0000
# test Running Loss: 449.1385 Running Acc: 761.0000
# test Running Loss: 470.8275 Running Acc: 791.0000
# test Loss: 0.5893 Acc: 0.9900
# Epoch 88/99
# ----------
# test Running Loss: 141.8056 Running Acc: 253.0000
# test Running Loss: 282.0746 Running Acc: 508.0000
# test Running Loss: 425.6628 Running Acc: 760.0000
# test Running Loss: 456.2107 Running Acc: 789.0000
# test Loss: 0.5710 Acc: 0.9875
# Epoch 89/99
# ----------
# test Running Loss: 148.5530 Running Acc: 253.0000
# test Running Loss: 294.5495 Running Acc: 503.0000
# test Running Loss: 428.6250 Running Acc: 757.0000
# test Running Loss: 461.8843 Running Acc: 786.0000
# test Loss: 0.5781 Acc: 0.9837
# Epoch 90/99
# ----------
# test Running Loss: 144.9554 Running Acc: 251.0000
# test Running Loss: 281.5864 Running Acc: 506.0000
# test Running Loss: 415.8470 Running Acc: 761.0000
# test Running Loss: 441.5126 Running Acc: 789.0000
# test Loss: 0.5526 Acc: 0.9875
# Epoch 91/99
# ----------
# test Running Loss: 139.4449 Running Acc: 252.0000
# test Running Loss: 284.3934 Running Acc: 505.0000
# test Running Loss: 417.0165 Running Acc: 757.0000
# test Running Loss: 446.2103 Running Acc: 787.0000
# test Loss: 0.5585 Acc: 0.9850
# Epoch 92/99
# ----------
# test Running Loss: 143.5717 Running Acc: 252.0000
# test Running Loss: 270.5860 Running Acc: 506.0000
# test Running Loss: 411.0685 Running Acc: 759.0000
# test Running Loss: 441.6468 Running Acc: 789.0000
# test Loss: 0.5527 Acc: 0.9875
# Epoch 93/99
# ----------
# test Running Loss: 129.6651 Running Acc: 255.0000
# test Running Loss: 257.5760 Running Acc: 509.0000
# test Running Loss: 391.2660 Running Acc: 762.0000
# test Running Loss: 411.0999 Running Acc: 793.0000
# test Loss: 0.5145 Acc: 0.9925
# Epoch 94/99
# ----------
# test Running Loss: 135.6382 Running Acc: 255.0000
# test Running Loss: 253.2184 Running Acc: 509.0000
# test Running Loss: 392.8556 Running Acc: 762.0000
# test Running Loss: 422.3702 Running Acc: 792.0000
# test Loss: 0.5286 Acc: 0.9912
# Epoch 95/99
# ----------
# test Running Loss: 132.0557 Running Acc: 251.0000
# test Running Loss: 268.2360 Running Acc: 503.0000
# test Running Loss: 404.1062 Running Acc: 757.0000
# test Running Loss: 430.7473 Running Acc: 787.0000
# test Loss: 0.5391 Acc: 0.9850
# Epoch 96/99
# ----------
# test Running Loss: 117.0402 Running Acc: 255.0000
# test Running Loss: 244.5396 Running Acc: 510.0000
# test Running Loss: 382.7198 Running Acc: 762.0000
# test Running Loss: 409.8894 Running Acc: 791.0000
# test Loss: 0.5130 Acc: 0.9900
# Epoch 97/99
# ----------
# test Running Loss: 126.0272 Running Acc: 253.0000
# test Running Loss: 260.4967 Running Acc: 506.0000
# test Running Loss: 399.2725 Running Acc: 760.0000
# test Running Loss: 417.9116 Running Acc: 791.0000
# test Loss: 0.5230 Acc: 0.9900
# Epoch 98/99
# ----------
# test Running Loss: 116.6964 Running Acc: 255.0000
# test Running Loss: 229.4547 Running Acc: 508.0000
# test Running Loss: 351.7238 Running Acc: 763.0000
# test Running Loss: 372.9087 Running Acc: 793.0000
# test Loss: 0.4667 Acc: 0.9925
# Epoch 99/99
# ----------
# test Running Loss: 129.2285 Running Acc: 254.0000
# test Running Loss: 235.1449 Running Acc: 509.0000
# test Running Loss: 362.1950 Running Acc: 763.0000
# test Running Loss: 380.4561 Running Acc: 794.0000
# test Loss: 0.4762 Acc: 0.9937
# Training complete in 20m 58s
